# %%
## This code performs VerbNet parsing using Docker container
# Use Selenium environment
# Source: https://github.com/jgung/verbnet-parser
# Follow the github instructions for running Docker container on localhost
# Website version: https://verbnetparser.com/

# Import selenium and other libraries needed for parsing html and running javascript code on browser
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.edge.options import Options
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup

from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import sentence_embeds_processing as sep
from sentence_embeds_processing import load_set_of_sentences, tokenise_sentence

import json
import csv
import regex as re
import numpy as np

# Root for data path
path_root = "D:\Study and Projects\School Work\Year 25 - PhD\Data"

# Lists of special words
stop_words = ['a', 'an', 'the', 'these', 'that', 'those', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', '']
special_word_list = {'tshirt':'t_shirt', 'lorises':'loris', 'allocates':'allocate', 'beared':'bears', 'comeing':'coming'}

# %%
## Key functions for parsing VerbNet

# Try to print specific semantic role from sentence
def get_semant_ele(sentence,element):
    try:
        return(sentence[element])
    except KeyError:
        return('NONE')
    

# Function to submit sentence to VerbNet browser-based app and return the html
def VerbNet_api(sentence, silent=True):
    if silent==True: # suppress showing  browser
        options = Options()
        options.add_argument("--headless")
  
    # prepare web driver to access url
    driver_path = Service('D:\Downloads\Archive\edgedriver_win64\msedgedriver.exe') # need to update this when Edge updates
    driver = webdriver.Edge(service=driver_path, options=options)
    url = "http://localhost:8080/" # need Docker running on localhost for this to work
    driver.get(url)

    # send sentence as input to form
    input = driver.find_element(by=By.TAG_NAME, value="input")
    input.send_keys(sentence)

    # submit form
    submit = driver.find_element(by=By.TAG_NAME, value="button")
    submit.click()

    # get url after submitting form
    web_output = driver.find_element(by=By.TAG_NAME, value="body")
    return(web_output)


# Modify a sentence by converting main verb to infinitive form, to help the parse when it gets stuck
def modify_sentence(sentence):
    tokenised_sentence = tokenise_sentence(sentence)
    likely_verb = tokenised_sentence[1]
    new_verb = 'is '+PorterStemmer().stem(likely_verb)+'ing'
    alt_sentence = re.sub(likely_verb, new_verb, sentence)
    return(alt_sentence)


# Function to extract the semantic tags from the VerbNet html
def extract_tags(web_output, role_transforms):
    html = web_output.get_attribute('innerHTML')
    soup = BeautifulSoup(html, 'html.parser')
    all_results = soup.find_all(class_="ui basic label") # get a big list of everything

    phrase_tags_dict = {}
    for element in all_results: # loop over elements in html
        phrase = element.find_all(class_=["ui black large basic label"]) # get phrase text
        tag = element.find_all(class_=["ui blue large basic label", "ui blue large label", "ui grey large basic label"]) # get tag text
        if len(tag)==0: # in case we don't find it using the normal search
            tag = element.find_all(class_=["detail"])
        if len(tag)==0: # last ditch case to find a tag
            tag = element.find_all(class_=["ui purple large basic label"])

        tag = tag[0].text # get just the tag text
        tag = re.sub(r',', '', tag) # remove commas from tag names (a few have them)
        phrase = phrase[0].text
        
        try:
            tag = role_transforms[tag] # perform transformation of tag if needed
        except KeyError:
            tag = tag # no transformation needed
            
        if bool(re.search('\d', tag)): # if there are numbers in the tag, its a verb (wordnet ID)
            tag = 'Verb'
        
        phrase_tags_dict[tag] = phrase # store results in dictionary

    if ('Agent' not in phrase_tags_dict.keys()) and ('Theme' in phrase_tags_dict.keys()): # rename 'Theme' to 'Agent' if Agent missing
        phrase_tags_dict['Agent'] = phrase_tags_dict['Theme']
        phrase_tags_dict.pop('Theme')
        
    output = (phrase_tags_dict, all_results)
    return(output)


# Load transformations for role labels from text file
def load_semantic_role_label_transforms():
    role_transforms = {}
    with open(path_root+'\Frames and Structured Data\VerbNet\VerbNet_parse_transformations.txt', newline='') as text_file:
        reader = csv.DictReader(text_file)
        for row in reader:
            role_transforms[row['initial']] = row['new']
    return(role_transforms)

# %%
## Show available datasets, as specified in the sep module
pairs = True # specify if we are using paired data or list of sentences
if pairs==True:
    datasets = sep.available_pair_datasets
else:
    datasets = sep.available_nonpaired_datasets
print('Available datasets:')
for dataset in datasets.keys():
    print(dataset,datasets[dataset])
# Out:
# {0: '2014 Wehbe\\Stimuli\\Chapter_9_sentences_final', 1: '2017 Anderson\\Stimuli\\stimuli_final', 2: '2018 Pereira\\Stimuli\\stimuli_243sentences', 3: '2018 Pereira\\Stimuli\\stimuli_384sentences', 4: '2020 Alice Dataset\\Stimuli\\stimuli_sentences_final', 5: 'Fodor_2023', 6: 'Fodor_2023_prelim'}
# loaded Fodor_2023

# %%
## Load sentence set 

# choose number from those printed above
dataset_name = datasets[5]

# load sentence set into dictionary depending on type
if pairs == True:
    sentences_dict = sep.load_set_of_sentences(dataset_name, file_paths_dict['data_pairs_path'], pairs)
else:
    sentences_dict = sep.load_set_of_sentences(dataset_name, file_paths_dict['neuro_root'], pairs)
n = len(sentences_dict.keys()) # num sentences
print('\nloaded',dataset_name,'with',n,'sentences')

# store in list
sentences = []
if pairs==True: # use this for sentence similarity pair data
    sentences.append(list(np.array(list(sentences_dict.values()))[:,0].flatten()))
    sentences.append(list(np.array(list(sentences_dict.values()))[:,1].flatten()))
else: # use this for neuroimaging data/list of sentences
    sentences.append(list(sentences_dict.values()))

# %%
## Perform VerbNet parse of dataset 
# Try restarting browser if Docker won't run; might need to try restarting the container a few times
sentence_pairs_parsed = {}
role_transforms = load_semantic_role_label_transforms() # get semantic role transformations from file

# Loop over all sentences
for key in list(sentences_dict.keys()):
    sentence_pair_parsed = []
    if (key%25==0):
        print('Index '+str(key))
    for sentence in sentences_dict[key][0:2]:
        print(sentence)
        web_output = VerbNet_api(sentence) # get html from web api
        parse_data, all_results = extract_tags(web_output, role_transforms) # extract parse results from html
        
        # try alternate formulation of a sentence if original version doesn't parse
        if parse_data=={}:
            alt_sentence = modify_sentence(sentence)
            web_output = VerbNet_api(alt_sentence) # get html from web api
            parse_data, all_results = extract_tags(web_output, role_transforms) # extract parse results from html
        
        sentence_pair_parsed.append(parse_data)
        print(parse_data)
    sentence_pairs_parsed[key] = sentence_pair_parsed # full data storage
    
# Save raw VerbNet parsed data into json file  
json_path = "full_verbnet_pass_"+dataset+"_raw.json"
with open(json_path, "w") as file:
    json.dump(sentence_pairs_parsed, file)

# %%
## Print out key roles with values in array-like format

# List of key semantic roles to use
sem_role_dict = {'Agent':0,'Verb':1,'Adjective':2,'Patient':3,'Theme':4,'Time':5,'Manner':6,'Location':7,'Trajectory':8,'Attribute':9}
num_roles = len(sem_role_dict.keys())
sent_1_store = np.empty((0,num_roles), dtype=object)
sent_2_store = np.empty((0,num_roles), dtype=object)
separator = '; '

# Loop over and print semantic roles for all sentence pairs
for key in sentence_pairs_parsed.keys():
    sents = sentence_pairs_parsed[key]
    
    # Get roles for first sentence
    set_of_roles = np.zeros(num_roles, dtype=object)
    for role in sem_role_dict.keys():
        role_index = sem_role_dict[role]
        set_of_roles[role_index] = get_semant_ele(sents[0],role) # add element in role
    sent_1_store = np.vstack([sent_1_store, set_of_roles]) # add this sent to storage array
    
    # Get roles for first sentence
    set_of_roles = np.zeros(num_roles, dtype=object)
    for role in sem_role_dict.keys():
        role_index = sem_role_dict[role]
        set_of_roles[role_index] = get_semant_ele(sents[1],role) # add element in role
    sent_2_store = np.vstack([sent_2_store, set_of_roles]) # add this sent to storage array
    
# Print out set of sentences and roles
all_lines = []
for i in np.arange(len(sentences_dict)):
    print_string_sent_1 = ''
    print_string_sent_2 = ''
    for j in range(num_roles):
        print_string_sent_1+=sent_1_store[i][j]+';'
        print_string_sent_2+=sent_2_store[i][j]+';'
    new_line = print_string_sent_1+';'+print_string_sent_2
    all_lines.append(new_line)
    # print(new_line)
    
# Save list of parsed data to text file  
text_path = "full_verbnet_pass_"+dataset+"_array.txt"
np.savetxt(text_path, np.array(all_lines), fmt='%s')
# Out:
# Cord;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;strong , thick string;;A smile;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;the expression that you ... you are being friendly;
# A rooster;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an adult male chicken;;A voyage;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a long journey on a ship or in a spacecraft;
# Noon;is;NONE;NONE;NONE;in the middle of the day;NONE;NONE;NONE;twelve o'clock;;String;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;thin rope made of twiste...her or tying up parcels;
# Fruit or a fruit;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;something which grows on...stance that you can eat;;NONE;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a container or enclosed space;
# An autograph;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;the signature of someone...itten for a fan to keep;;The shores or shore of a sea , lake or wide river;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;the land along the edge of it;
# An automobile;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a car;;a wizard;is;NONE;NONE;NONE;NONE;NONE;In legends and fairy stories;NONE;a man who has magic powers;
# A mound of something;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a large rounded pile of it;;A stove;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a piece of equipment whi...g or for heating a room;
# A grin;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a broad smile;;An implement;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a tool or other piece of equipment;
# An Asylum;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a psychiatric hospital;;Fruit or a fruit;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;something which grows on...stance that you can eat;
# An Asylum;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a psychiatric hospital;;A monk;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a member of a male relig... from the outside world;
# A graveyard;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an area of land , someti... dead people are buried;;you;describe;NONE;NONE;a place or situation;NONE;NONE;NONE;NONE;as a madhouse;
# Glass;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a hard transpare not sub... as windows and bottles;;people;entertains;NONE;NONE;who;NONE;by doing magic tricks;NONE;NONE;NONE;
# A boy;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a child who will grow up to be a man;;A rooster;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an adult male chicken;
# A cushion;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a fabric case filled wit...ake it more comfortable;;A jewel;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a precious stone used to...h as rings or necklaces;
# A monk;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a member of a male relig... from the outside world;;A slave;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;someone who is the prope...to work for that person;
# An Asylum;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a psychiatric hospital;;A cemetery;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a place where dead peopl... their ashes are buried;
# The coast;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an area of land that is next to the sea;;A forest;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a large area where trees grow close together;
# A grin;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a broad smile;;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;
# The shores or shore of a sea , lake or wide river;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;the land along the edge of it;;Woodland;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;land with a lot of trees;
# A monk;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a member of a male relig... from the outside world;;an oracle;was;NONE;NONE;NONE;In ancient times;NONE;NONE;NONE;a priest or priestess wh...ents or about the truth;
# A boy;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a child who will grow up to be a man;;a person;regarded;NONE;NONE;NONE;NONE;NONE;NONE;NONE;as being very wise;
# An automobile;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a car;;A cushion;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a fabric case filled wit...ake it more comfortable;
# A mound of something;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a large rounded pile of it;;The shores or shore of a sea , lake or wide river;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;the land along the edge of it;
# NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;;a wizard;is;NONE;NONE;NONE;NONE;NONE;In legends and fairy stories;NONE;a man who has magic powers;
# A forest;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a large area where trees grow close together;;A graveyard;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an area of land , someti... dead people are buried;
# Food;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;what people and animals eat;;A rooster;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an adult male chicken;
# A cemetery;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a place where dead peopl... their ashes are buried;;Woodland;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;land with a lot of trees;
# The shores or shore of a sea , lake or wide river;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;the land along the edge of it;;A voyage;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a long journey on a ship or in a spacecraft;
# A bird;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a creature with feathers and wings;;Woodland;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;land with a lot of trees;
# The coast;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an area of land that is next to the sea;;A hill;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an area of land that is ... land that surrounds it;
# NONE;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a container or enclosed space;;An implement;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a tool or other piece of equipment;
# that;moves;NONE;NONE;heavy things;NONE;by lifting them in the air;NONE;NONE;NONE;;A rooster;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an adult male chicken;
# A hill;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an area of land that is ... land that surrounds it;;Woodland;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;land with a lot of trees;
# A car;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a motor vehicle with roo...ll number of passengers;;you;journey;NONE;NONE;NONE;When;NONE;NONE;NONE;NONE;
# A cemetery;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a place where dead peopl... their ashes are buried;;A mound of something;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a large rounded pile of it;
# Glass;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a hard transpare not sub... as windows and bottles;;A jewel;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a precious stone used to...h as rings or necklaces;
# people;entertains;NONE;NONE;who;NONE;by doing magic tricks;NONE;NONE;NONE;;an oracle;was;NONE;NONE;NONE;In ancient times;NONE;NONE;NONE;a priest or priestess wh...ents or about the truth;
# that;moves;NONE;NONE;heavy things;NONE;by lifting them in the air;NONE;NONE;NONE;;An implement;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a tool or other piece of equipment;
# Your brother;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a boy or a man who has the same parents as you;;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;
# a person;regarded;NONE;NONE;NONE;NONE;NONE;NONE;NONE;as being very wise;;a wizard;is;NONE;NONE;NONE;NONE;NONE;In legends and fairy stories;NONE;a man who has magic powers;
# an oracle;was;NONE;NONE;NONE;In ancient times;NONE;NONE;NONE;a priest or priestess wh...ents or about the truth;;a person;regarded;NONE;NONE;NONE;NONE;NONE;NONE;NONE;as being very wise;
# A bird;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a creature with feathers and wings;;that;moves;NONE;NONE;heavy things;NONE;by lifting them in the air;NONE;NONE;NONE;
# A bird;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a creature with feathers and wings;;A cock;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an adult male chicken;
# Food;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;what people and animals eat;;Fruit or a fruit;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;something which grows on...stance that you can eat;
# Your brother;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a boy or a man who has the same parents as you;;A monk;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a member of a male relig... from the outside world;
# An Asylum;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a psychiatric hospital;;you;describe;NONE;NONE;a place or situation;NONE;NONE;NONE;NONE;as a madhouse;
# NONE;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a container or enclosed space;;A stove;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a piece of equipment whi...g or for heating a room;
# people;entertains;NONE;NONE;who;NONE;by doing magic tricks;NONE;NONE;NONE;;a wizard;is;NONE;NONE;NONE;NONE;NONE;In legends and fairy stories;NONE;a man who has magic powers;
# A hill;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an area of land that is ... land that surrounds it;;A mound of something;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a large rounded pile of it;
# Cord;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;strong , thick string;;String;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;thin rope made of twiste...her or tying up parcels;
# Glass;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a hard transpare not sub... as windows and bottles;;A tumbler;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a drinking glass with straight sides;
# A grin;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a broad smile;;A smile;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;the expression that you ... you are being friendly;
# serfs;were;NONE;NONE;NONE;In former times;NONE;NONE;NONE;a class of people who ha...at person 's permission;;A slave;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;someone who is the prope...to work for that person;
# you;journey;NONE;NONE;NONE;When;NONE;NONE;NONE;NONE;;A voyage;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a long journey on a ship or in a spacecraft;
# An autograph;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;the signature of someone...itten for a fan to keep;;Your signature;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;your name , written in y...agree with what it says;
# The coast;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an area of land that is next to the sea;;The shores or shore of a sea , lake or wide river;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;the land along the edge of it;
# A forest;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a large area where trees grow close together;;Woodland;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;land with a lot of trees;
# An implement;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a tool or other piece of equipment;;you;hold;NONE;NONE;that;NONE;NONE;in your hands;NONE;NONE;
# A cock;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an adult male chicken;;A rooster;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an adult male chicken;
# A boy;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a child who will grow up to be a man;;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;
# A cushion;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a fabric case filled wit...ake it more comfortable;;you;rest;NONE;NONE;your head;when you are in bed;NONE;on;NONE;NONE;
# A cemetery;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a place where dead peopl... their ashes are buried;;A graveyard;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;an area of land , someti... dead people are buried;
# An automobile;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a car;;A car;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a motor vehicle with roo...ll number of passengers;
# Midday;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;twelve o'clock in the middle of the day;;Noon;is;NONE;NONE;NONE;in the middle of the day;NONE;NONE;NONE;twelve o'clock;
# A gem;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a jewel or stone that is used in jewellery;;A jewel;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a precious stone used to...h as rings or necklaces;
# you;like;NONE;NONE;to go out to drink with me tonight;NONE;NONE;NONE;NONE;NONE;;I;know;NONE;NONE;what to eat tonight;NONE;really;NONE;NONE;NONE;
# I;advise;NONE;you;to treat this matter very seriously as it is vital;NONE;NONE;NONE;NONE;NONE;;You;take;NONE;NONE;this;NONE;most seriously;NONE;NONE;NONE;
# I;going;NONE;NONE;to meet my friends;When;NONE;NONE;out;NONE;;The train operator;announced;NONE;to the passengers;that the train would be delayed;NONE;NONE;NONE;NONE;NONE;
# music;help;NONE;you;to relax;NONE;NONE;NONE;NONE;NONE;;to you;look;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;
# NONE;punished;NONE;you;NONE;NONE;if you play with the alarm;NONE;NONE;NONE;;for setting the fire alarm off;punished;NONE;He;NONE;NONE;harshly;NONE;NONE;NONE;
# I;make;NONE;you laugh so much that your sides ache;NONE;NONE;NONE;NONE;NONE;NONE;;I;tell;NONE;you;this;When;NONE;NONE;NONE;NONE;
# You;covering;NONE;NONE;NONE;NONE;NONE;what you really feel;NONE;NONE;;no point in covering up what you said;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;
# you;want;NONE;NONE;to come with us to the pub behind the hill;NONE;NONE;NONE;NONE;NONE;;We;going;NONE;NONE;for drinks;tonight;if you would like to come;in Salford Quays;out;NONE;
# to be working;seem;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;;I;dislike;NONE;NONE;the word quay;NONE;NONE;NONE;NONE;NONE;
# The ghost;appeared;NONE;NONE;NONE;NONE;NONE;NONE;from nowhere;NONE;;The ghost of Queen Victoria;appears;NONE;NONE;NONE;every night;NONE;to me;NONE;NONE;
# You;are;NONE;NONE;NONE;NONE;if you are not prepared ...present when I need you;NONE;NONE;a good friend;;to be present when you need them;seems;NONE;NONE;NONE;always;NONE;NONE;NONE;NONE;
# The children;crossed;NONE;NONE;NONE;NONE;very safely;NONE;the road;NONE;;that the child might not...se he was seriously ill;feared;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;
# I;invited;NONE;NONE;a variety of people;NONE;NONE;NONE;NONE;NONE;;to a variety of people inviting them down the pub;given out;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;
# I;offer;NONE;NONE;my condolences;NONE;NONE;NONE;NONE;NONE;;I;express;NONE;to John Smith 's parents;my sympathy;following his murder;NONE;NONE;NONE;NONE;
# Boats;come;NONE;NONE;NONE;NONE;in all shapes and sizes;NONE;NONE;NONE;;Chairs;be;NONE;NONE;NONE;NONE;depending on the chair;NONE;NONE;comfy and not comfy;
# you;use;NONE;NONE;these products;NONE;continuously;NONE;NONE;NONE;;I;assure;NONE;you;that , by using these pr...ill appear really young;NONE;NONE;NONE;NONE;NONE;
# We;ran;NONE;NONE;NONE;that day;NONE;farther than the other children;NONE;NONE;;You;ran;NONE;NONE;NONE;today;farther than anyone;NONE;NONE;NONE;
# I;like;NONE;NONE;to have a slice of lemon...specially if it 's Coke;always;NONE;NONE;NONE;NONE;;I;like;NONE;NONE;to put a wedge of lemon ...rinks , especially cola;NONE;NONE;NONE;NONE;NONE;
# like I have got eczema on my ear doctor;seems;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;;I;go;NONE;NONE;for a special rash cream for my ear;NONE;NONE;NONE;NONE;NONE;
# I;am;NONE;NONE;NONE;NONE;NONE;NONE;NONE;proud of our nation;;I;think;NONE;NONE;of myself;NONE;NONE;NONE;NONE;as being part of a nation;
# by the builders;left;NONE;NONE;a heap of rubble;this morning;NONE;outside my house;NONE;NONE;;accidents;happen;NONE;NONE;NONE;Sometimes;which can cause deadly injuries;in a large crowd;NONE;NONE;
# NONE;freezes;NONE;Water;NONE;NONE;at a certain temperature...is zero degrees Celsius;NONE;NONE;NONE;;NONE;boiling;NONE;water;NONE;NONE;NONE;NONE;NONE;NONE;
# NONE;home;NONE;We;NONE;in the end;although it was a long journey;NONE;NONE;NONE;;many hours travel;took;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;
# Dave;called;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;;The man;presented;NONE;to the woman;a diamond;NONE;NONE;NONE;NONE;NONE;
# I;run;NONE;NONE;NONE;NONE;quite a lot;NONE;NONE;NONE;;I;climb;NONE;NONE;NONE;NONE;lots;at school;NONE;NONE;
# I;love;NONE;NONE;to laugh as it makes me ...well as those around me;NONE;NONE;NONE;NONE;NONE;;I;thought;NONE;NONE;we bargained that it would only cost me a pound;NONE;NONE;NONE;NONE;NONE;
# I;am;NONE;NONE;NONE;NONE;NONE;NONE;NONE;the eldest one;;people;think;NONE;NONE;I am a responsible adult;NONE;NONE;NONE;NONE;NONE;
# I;need;NONE;NONE;to dash into the kitchen... my chip pan is on fire;NONE;NONE;NONE;NONE;NONE;;chip pan;fire;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;
# Peter;was;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a very large youth , who...e , much to his delight;;I;say;NONE;NONE;he was fat;Now;NONE;NONE;NONE;NONE;
# I;buy;NONE;NONE;a grey jumper;in half an hour;NONE;NONE;NONE;NONE;;you;get;NONE;NONE;from;NONE;NONE;NONE;NONE;NONE;
# NONE;soaked;NONE;NONE;NONE;today;NONE;in the rain;NONE;NONE;;wet;soaking;NONE;NONE;NONE;last night;absolutely;I;NONE;NONE;
# NONE;warming;NONE;Global;NONE;NONE;NONE;NONE;NONE;NONE;;NONE;warming;NONE;global;NONE;NONE;NONE;NONE;NONE;NONE;
# for setting the fire alarms off;punished;NONE;He;NONE;NONE;harshly;NONE;NONE;NONE;;He;delayed;NONE;NONE;in order to create a tense atmosphere;NONE;NONE;NONE;NONE;NONE;
# Midday;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;twelve o'clock in the middle of the day;;Noon;is;NONE;NONE;NONE;in the middle of the day;NONE;NONE;NONE;twelve o'clock;
# mine;is;NONE;NONE;NONE;NONE;on the other hand;NONE;NONE;great;;This;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a terrible noise level for a new car;
# a terrible accident , a pileup ,;was;NONE;NONE;NONE;today;NONE;on the road;NONE;NONE;;It;was;NONE;NONE;NONE;NONE;NONE;NONE;NONE;a terrible accident;
# we;arrived;NONE;NONE;NONE;eventually;NONE;at the hotel;NONE;NONE;;against the strong wind;walking;NONE;NONE;NONE;for hours;NONE;NONE;NONE;NONE;
# I;do;NONE;NONE;The first thing;in a morning;NONE;NONE;NONE;NONE;;I;do;NONE;NONE;The first thing;in the morning;NONE;NONE;NONE;NONE;
# Someone;spilt;NONE;NONE;a drink;NONE;accidentally;on my shirt;NONE;NONE;;to have shrunk;appears;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;
# I;am;NONE;NONE;NONE;NONE;NONE;NONE;NONE;worried most seriously a...ntation , not the essay;;to gain full marks in today 's exam;is;NONE;NONE;NONE;NONE;mostly;NONE;NONE;very difficult;
# to gain full marks in today 's exam;is;NONE;NONE;NONE;NONE;mostly;NONE;NONE;very difficult;;The exam;was;NONE;NONE;NONE;NONE;NONE;NONE;NONE;really difficult;
# me;Meet;NONE;NONE;NONE;in half an hour;NONE;on the hill behind the church;NONE;NONE;;NONE;Join;NONE;me;NONE;in thirty minutes time;NONE;at the back of the church;NONE;NONE;
# you;console;NONE;NONE;NONE;NONE;with a friend;NONE;NONE;NONE;;One of the qualities of a good friend;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;the ability to console;
# We;tried;NONE;NONE;to bargain with him;NONE;NONE;NONE;NONE;NONE;;I;tried;NONE;NONE;bargaining with him;NONE;NONE;NONE;NONE;NONE;
# to announce the winner o... year 's beauty pageant;gives;NONE;me;great pleasure;NONE;NONE;NONE;NONE;NONE;;who has won our annual beauty parade;tell;NONE;you;NONE;NONE;NONE;NONE;NONE;NONE;
# They;said;NONE;NONE;they were hoping to go to America on holiday;NONE;NONE;NONE;NONE;NONE;;I;like;NONE;NONE;to cover myself up in lots of layers;NONE;NONE;NONE;NONE;NONE;
# I;drive;NONE;NONE;to get to the nearest petrol station;NONE;NONE;far;NONE;NONE;;for me to drive to the next gas station;Is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;much farther;
# I;think;NONE;NONE;I know her from somewher...she has a familiar face;NONE;NONE;NONE;NONE;NONE;;You;have;NONE;NONE;a very familiar face;NONE;NONE;NONE;NONE;NONE;
# I;am;NONE;NONE;NONE;NONE;NONE;NONE;NONE;sorry;;I;have;NONE;NONE;a heap of things to finish;NONE;NONE;NONE;NONE;NONE;
# The responsible man;felt;NONE;NONE;very guilty;when he crashed into the back of someone 's car;NONE;NONE;NONE;NONE;;A slow driver;be;NONE;NONE;NONE;NONE;even though they are driving safely;NONE;NONE;annoying;
# NONE;off my brand new white sofa;NONE;that wet dog;NONE;NONE;NONE;NONE;NONE;NONE;;NONE;Make;NONE;that wet hound get off my white couch;NONE;NONE;NONE;NONE;NONE;NONE;
# He;fought;NONE;NONE;NONE;before being killed in a car crash;NONE;in the war in Iraq;NONE;NONE;;I;suffered;NONE;NONE;The prejudice;whilst on holiday in Iraq;NONE;NONE;NONE;NONE;
# The cat;was;NONE;NONE;NONE;NONE;NONE;NONE;NONE;hungry;;The hen;walked;NONE;NONE;NONE;NONE;eating tasty grain;in the yard;NONE;NONE;
# My bedroom wall;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;lemon coloured;;Roses;be;NONE;NONE;NONE;NONE;NONE;NONE;NONE;different colours;
# you;like;NONE;NONE;to drink this wine with your meal;NONE;NONE;NONE;NONE;NONE;;you;drink;NONE;a glass of wine;NONE;while you eat;NONE;NONE;NONE;NONE;
# Roses;be;NONE;NONE;NONE;NONE;NONE;NONE;NONE;different colours;;Roses;come;NONE;NONE;NONE;NONE;in many varieties and colours;NONE;NONE;NONE;
# a lot of disease;carry;NONE;NONE;NONE;NONE;NONE;Flies;NONE;NONE;;I;dry;NONE;my hair;NONE;after I wash it;NONE;NONE;NONE;NONE;
# you;climb;NONE;NONE;NONE;NONE;NONE;NONE;up the tree;NONE;;you;get;NONE;NONE;NONE;NONE;NONE;NONE;up that tree;NONE;
# I;get;NONE;NONE;from studying;NONE;NONE;NONE;NONE;NONE;;I;doubt;NONE;NONE;about this exam;NONE;NONE;NONE;NONE;NONE;
# The perpetrators of war crimes;are;NONE;NONE;NONE;NONE;NONE;NONE;NONE;rotten to the core;;many global issues that ...the threat of terrorism;are;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;
# NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;;from the sun;burnt;NONE;The young lady;NONE;NONE;somewhat partially;NONE;NONE;NONE;
# We;ran;NONE;NONE;NONE;often;NONE;to school;NONE;NONE;;I;knew;NONE;NONE;I was late for my class;NONE;NONE;NONE;NONE;NONE;
# I;hope;NONE;NONE;you are taking this seriously;NONE;NONE;NONE;NONE;NONE;;that only the strong would survive;meant;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;
# The shores or shore of a sea , lake or wide river;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;the land along the edge of it;;An autograph;is;NONE;NONE;NONE;NONE;NONE;NONE;NONE;the signature of someone...itten for a fan to keep;
# I;bought;NONE;NONE;a new guitar;today;NONE;NONE;NONE;NONE;;weapon;choice;NONE;NONE;NONE;NONE;NONE;NONE;NONE;NONE;
# I;am;NONE;NONE;NONE;NONE;NONE;NONE;NONE;so hungry I could eat a whole horse plus dessert;;I;eaten;NONE;another meal;NONE;NONE;NONE;NONE;NONE;NONE;
