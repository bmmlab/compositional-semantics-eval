# %%
## This script computes VerbNet pairwise sentence similarities for Behavioural Data (paired)
# Requires that sentences have already been parsed using VerbNet semantic roles, as performed by 'Calc_parse_GPT4.ipynb'.
# Run using base python 3.9
# James Fodor 2023

# load libraries
import numpy as np
import json
import random
import itertools
import sentence_embeds_processing as sep
import seaborn as sns
import pickle

from sklearn.decomposition import PCA
from scipy.stats import spearmanr
from scipy.ndimage import convolve
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor

# base paths for data files
path_root = "D:\Study and Projects\School Work\Year 25 - PhD\Data\\"
data_pairs_path = path_root+'\\Sentence Similarity Data\\Sentence Similarities Final\\'
data_nonpaired_path = path_root+'\\Neuroimaging Data\\'
embeddings_path = "Analysis Results\Sentence Embeddings\\"
parse_path = "Analysis Results\Sentence Parses\\"
conceptnet_path = '\Word Embeddings\ConceptNet Embeddings\\numberbatch-en.txt'

# set fixed params
role_weights_dict = {'Agent':2, 'Verb':3, 'Patient':2, 'Theme':2, 'Time':0.5, 'Manner':0.5, 'Location':0.5, 'Trajectory':0.5}
role_weights_list = np.array(list(role_weights_dict.values()))/11
role_weights_list_augment = np.array(list(role_weights_dict.values())+[3])/12

# numpy print options
np.set_printoptions(precision=2, threshold=2000, linewidth=200, suppress=True, floatmode='fixed')
sns.set()

# define stop words
stop_words = np.loadtxt(path_root+'\Frames and Structured Data\FrameNet\\nltk_data\corpora\stopwords\english.txt', dtype='str') # list of stop words

# %% [markdown]
# ### Step 0: Load sentence dataset and parse

# %% [markdown]
# Load the dataset of sentences we want to compute VerbNet similarities for.

# %%
## Show available datasets, as specified in the sentence_embeds_processing module
pairs = False # specify if we are using paired data or list of sentences
if pairs==True:
    datasets = sep.available_pair_datasets
else:
    datasets = sep.available_nonpaired_datasets
for dataset in datasets.keys():
    print(dataset,datasets[dataset])
# Out:
# {0: 'GS2011_processed', 1: 'KS2013_processed', 2: 'Fodor_pilot_2022', 3: 'STS131_processed', 4: 'SICK_relatedness', 5: 'STSb_captions_test', 6: 'STSb_forums_test', 7: 'STSb_headlines_test', 8: 'STSb_test', 9: 'STS3k_all'}

# %%
## Load sentence set (choose number from those printed above)
dataset = datasets[5]
sentences_dict = sep.load_set_of_sentences(dataset, data_pairs_path, data_nonpaired_path, pairs)
full_dataset_name = sep.fix_sentence_dataset_name(dataset)
full_dataset_name = sep.extract_text_between('^([^_]+)',full_dataset_name)[0] # remove 'neuro' from name
n = len(sentences_dict.keys()) # num sentences
print('\nloaded',dataset,'with',n,'sentences')

# %%
## load parse data for the dataset
parse_type = 'GPT4' # choose parse type ('verbnet' or 'GPT4')
json_path = path_root+parse_path+parse_type+' Parsing\\full_'+parse_type+'_pass_'+full_dataset_name+'_mod.json'
sentence_pair_parsed_dict = json.load(open(json_path)) # load verbnet parse data from json
print('parse type:',parse_type)
print('sentences parsed:',n)

# %% [markdown]
# ### Step 1: Load experimental pairwise sentence similarities

# %% [markdown]
# Load the experimental (human) pairwise similarity judgements.

# %%
## Load experimental similarities from file

# Define key user-specified options
dataset_index_to_load = 9 # choose exprimental dataset to analyse
parse_type = 'VerbNet' # choose parse type ('verbnet' or 'GPT4')
start_index = 1 # slightly different way of storing data

# get experimental similarities for the dataset
if pairs==True:
    sim_storage = {}
    sim_storage['expr'] = np.array(list(sentences_dict.values()))[:,2].astype(float)
# Out:
# loaded: STS3k_all
# parse type: VerbNet

# %% [markdown]
# ### Step 2: Load embeddings model

# %%
## Load all the needed model embeddings for rolewise sims

# Load ConceptNet embeddings
model_address = path_root+conceptnet_path
conceptnet_embeds = sep.import_word_model(model_address)

# Load SentBERT model
# install here: https://www.sbert.net/
# from sentence_transformers import SentenceTransformer, util
# sentbert_model = SentenceTransformer(path_root+'\Sentence Embeddings\sentence-transformers-MiniLM-L6-v2')

# # Load AMRBART model
# from transformers import BartForConditionalGeneration
# config_state = AutoConfig.from_pretrained(path_root+'\Sentence Embeddings\\amrbart-large', output_hidden_states=True) # get hidden states
# amrbart_tokenizer = AutoTokenizer.from_pretrained(path_root+'\Sentence Embeddings\\amrbart-large', collapse_name_ops=False, use_pointer_tokens=True, raw_graph=False)
# amrbart_model = BartForConditionalGeneration.from_pretrained(path_root+'\Sentence Embeddings\\amrbart-large', config=config_state)

# %% [markdown]
# ### Step 3: Compute rolewise similarities (only do once)

# %% [markdown]
# Compute the rolewise similarities of two sentences using the VerbNet semantic role parses. This is the key step of computation and is very slow - maybe an hour per 1000 pairs. Only do this once and save the results.

# %%
## Functions to compute VerbNet rolewise similarities 

# Define special dictionaries and lists of words
tag_alignment_dict = [('Location','Trajectory'), ('Theme','Patient'), ('Theme','Manner'), ('Manner','Trajectory'), ('Patient','Location'), ('Patient','Manner')]

# Split a list up into n equal sublists
def partition_list(list_in, n):
    random.shuffle(list_in)
    return [list_in[i::n] for i in range(n)]


# Try to print specific semantic role from sentence
def get_semant_ele(sentence,element):
    try:
        return(sentence[element])
    except KeyError:
        return('NONE')
    

# Load word weights to adjust similarities for word frequency
def load_word_weights():
    # Load each line of fine into list
    filename = path_root+'\Corpus Data\Lambda Corpus\lambada-vocab.txt'
    with open(filename, encoding='utf-8') as file:
        words_raw = [line.rstrip('\n').split('\t') for line in file]

    # convert to dictionary    
    word_count_dict = {}
    for word in words_raw:
        word_count_dict[word[0]] = int(word[1])
        
    # compute word weights
    n = word_count_dict['<s>'] # total number of sentences in corpus
    word_weights = {} # store weights for each word
    for word in word_count_dict.keys():
        word_weights[word]= -np.log2(word_count_dict[word]/n)/10
    return word_weights


# Compute embedding for phrases from the verbnet parse using conceptnet
def phrase_embed(pair_id, phrase):
    # Split phrase into words and define storage
    word_list = sep.tokenise_sentence(phrase, stop_words)
    word_list = sep.replace_tricky_tokens(word_list)
    embed_length = len(conceptnet_embeds['man'])
    embeds = np.empty((0,embed_length), float)
    
    # Get word embeddings for each word in phrase
    for word in word_list:
        try:
            embeds = np.vstack([embeds,conceptnet_embeds[word.lower()]])
        except KeyError:
            print(pair_id,'couldn\'t find',word)
            continue # ignore words we can't find
    
    # Save final phrase embeddings
    if len(np.ndarray.flatten(embeds)) > embed_length: # deal with phrases with multiple embeddings
        phrase_embedding = np.mean(embeds, axis=0) # average over all saved embeddings
    else:
        try:
            phrase_embedding = embeds[0] # use embeddings for single word
        except IndexError:
            phrase_embedding = np.zeros(embed_length) # return array of zeros if no words in phrase found
    
    return(phrase_embedding)


# Compute the weighted phrase similiarity for matching pair of phrases
def calc_weighted_phrase_sim(pair_id, phrase_1, phrase_2, weighting):
    phrase_embed_1 = phrase_embed(pair_id, phrase_1)
    phrase_embed_2 = phrase_embed(pair_id, phrase_2)
    try:
        word_weights = load_word_weights()
        phrase_1_weight = max(word_weights[word] for word in phrase_1.split(' '))
        phrase_2_weight = max(word_weights[word] for word in phrase_2.split(' '))
        sim = sep.cosine_sim(phrase_embed_1,phrase_embed_2) # compute phrase cosine similarity
        if weighting==True:
            return max(phrase_1_weight,phrase_2_weight)*sim # weight sim by phrase sims to account for word rarity
        else:
            return sim # version without word frequency weighting
    except KeyError:
        sim = 0 # return zero if can't find word weights
        return sim


# Compute the hybrid conceptnet-sentbert phrase similiarity for matching pair of phrases
def calc_hybrid_phrase_sim(pair_id, phrase_1, phrase_2, weighting=True, cutoff=2):
    # in the case of long phrases, long being greater than cutoff
    if (len(tokenise_sentence(phrase_1)) > cutoff) and (len(tokenise_sentence(phrase_1)) > cutoff):
        final_sim = sentbert_sim([phrase_1, phrase_2])[0]
    # otherwise use weighted conceptnet embeds
    else:
        final_sim = calc_weighted_phrase_sim(pair_id, phrase_1, phrase_2, weighting)
    return final_sim


# Compute similarity of non-identical but matching tags, as determined by the tag_alignment_dict
def align_tags(sim_storage_dict, sentence_pair_parsed_dict, pair_id, tag_1, tag_2, sent_1_tags, sent_2_tags, sim_type, cutoff):
    if ((tag_1 in sent_1_tags) and (tag_1 not in sent_2_tags) and (tag_2 in sent_2_tags) and (tag_2 not in sent_1_tags)):
        # compute similarity of newly matched tags
        phrase_1 = sentence_pair_parsed_dict[pair_id][0][tag_1].lower()
        phrase_2 = sentence_pair_parsed_dict[pair_id][1][tag_2].lower()
        
        # compute different types of similarities for phrase pairs of given role tag
        if sim_type=='sentbert':
            phrase_sim = float(sentbert_sim([phrase_1, phrase_2])[0])
        elif sim_type=='conceptnet_wtd':
            phrase_sim = float(calc_weighted_phrase_sim(pair_id, phrase_1, phrase_2, weighting=True))
        elif sim_type=='conceptnet':
            phrase_sim = float(calc_weighted_phrase_sim(pair_id, phrase_1, phrase_2, weighting=False))
        elif sim_type=='hybrid_1' or sim_type=='hybrid_2':
            phrase_sim = float(calc_hybrid_phrase_sim(pair_id, phrase_1, phrase_2, weighting=True, cutoff=cutoff))
        
        # update storage of tags
        sim_storage_dict[tag_1] = phrase_sim
        sim_storage_dict.pop(tag_2)
        sentence_pair_parsed_dict[pair_id][1][tag_1] = sentence_pair_parsed_dict[pair_id][1][tag_2] # update name
        sentence_pair_parsed_dict[pair_id][1].pop(tag_2) 
        sent_2_tags.remove(tag_2) 
        
    elif ((tag_1 in sent_2_tags) and (tag_1 not in sent_1_tags) and (tag_2 in sent_1_tags) and (tag_2 not in sent_2_tags)):
        # compute similarity of newly matched tags
        phrase_1 = sentence_pair_parsed_dict[pair_id][0][tag_2].lower()
        phrase_2 = sentence_pair_parsed_dict[pair_id][1][tag_1].lower()
        
        # compute different types of similarities for phrase pairs of given role tag
        if sim_type=='sentbert':
            phrase_sim = float(sentbert_sim([phrase_1, phrase_2])[0])
        elif sim_type=='conceptnet_wtd':
            phrase_sim = float(calc_weighted_phrase_sim(pair_id, phrase_1, phrase_2, weighting=True))
        elif sim_type=='conceptnet':
            phrase_sim = float(calc_weighted_phrase_sim(pair_id, phrase_1, phrase_2, weighting=False))
        elif sim_type=='hybrid_1' or sim_type=='hybrid_2':
            phrase_sim = float(calc_hybrid_phrase_sim(pair_id, phrase_1, phrase_2, weighting=True, cutoff=cutoff))
        
        # update storage of tags
        sim_storage_dict[tag_1] = phrase_sim
        sim_storage_dict.pop(tag_2)
        sentence_pair_parsed_dict[pair_id][0][tag_1] = sentence_pair_parsed_dict[pair_id][0][tag_2] # update name
        sentence_pair_parsed_dict[pair_id][0].pop(tag_2)
        sent_1_tags.remove(tag_2)
        
    return(sim_storage_dict)


# Compute similarity of non-identical but matching tags, as determined by the tag_alignment_dict
def align_tags_amrbart(sim_storage_dict, sentence_pair_parsed_dict, pair_id, tag_1, tag_2, sent_1_tags, sent_2_tags):
    if ((tag_1 in sent_1_tags) and (tag_1 not in sent_2_tags) and (tag_2 in sent_2_tags) and (tag_2 not in sent_1_tags)):
        # compute similarity of newly matched tags
        phrase_1 = sentence_pair_parsed_dict[pair_id][0][tag_1]
        phrase_2 = sentence_pair_parsed_dict[pair_id][1][tag_2]
        sim = sep.cosine_sim(phrase_1,phrase_2) # get weighted phrase similarity
        
        # update storage of tags
        sim_storage_dict[tag_1] = sim
        sim_storage_dict.pop(tag_2)
        sentence_pair_parsed_dict[pair_id][1][tag_1] = sentence_pair_parsed_dict[pair_id][1][tag_2] # update name
        sentence_pair_parsed_dict[pair_id][1].pop(tag_2) 
        sent_2_tags.remove(tag_2) 
        
    elif ((tag_1 in sent_2_tags) and (tag_1 not in sent_1_tags) and (tag_2 in sent_1_tags) and (tag_2 not in sent_2_tags)):
        # compute similarity of newly matched tags
        phrase_1 = sentence_pair_parsed_dict[pair_id][0][tag_2]
        phrase_2 = sentence_pair_parsed_dict[pair_id][1][tag_1]
        sim = sep.cosine_sim(phrase_1,phrase_2) # get weighted phrase similarity
        
        # update storage of tags
        sim_storage_dict[tag_1] = sim
        sim_storage_dict.pop(tag_2)
        sentence_pair_parsed_dict[pair_id][0][tag_1] = sentence_pair_parsed_dict[pair_id][0][tag_2] # update name
        sentence_pair_parsed_dict[pair_id][0].pop(tag_2)
        sent_1_tags.remove(tag_2)
        
    return(sim_storage_dict)


# Return the count of the number of sentences containing the relevant role over the entire dictionary
def get_role_counts(sentence_pair_parsed_dict, sent_id):
    all_tags = {}
    for sent_pair in sentence_pair_parsed_dict.values():
        for tag in list(sent_pair[sent_id].keys()):
            try:
                all_tags[tag]+=1
            except KeyError:
                all_tags[tag]=1
                
    return(all_tags)

# Function to convert role-wise dictionary sim storage into role-wise list storage
def dict_sim_to_list(role_weights_dict,sim_storage_dict):
    sim_storage_dict_full = {}
    for role in role_weights_dict.keys():
        try:
            sim_storage_dict_full[role] = sim_storage_dict[role]
        except KeyError:
            sim_storage_dict_full[role] = 0
    sim_storage_list = list(sim_storage_dict_full.values())
    
    return(sim_storage_list)

# %%
## Compute role-wise sentence similarities using VerbNet parses
word_weights = load_word_weights() # these are weights for weighted version of conceptnet sim

# initialse storage dictionaries
sim_storage_dict = {}
all_role_sim_storage_dict = {}
list_sim_funcs = ['conceptnet']
for sim_type in list_sim_funcs:
    sim_storage_dict[sim_type] = np.array([]) 

# compute all types of similarities over all sentence pairs
for sim_type in list_sim_funcs:
    # set the cutoff for hybrid sim functions
    if sim_type=='hybrid_1' or sim_type=='hybrid_2':
        hybrid_cutoff = int(sim_type[-1])
        
    # role sims storage dict
    role_sim_storage = {}
    
    sentence_pair_parsed_dict_mod = sentence_pair_parsed_dict.copy() # use a fresh copy of the parsed sentences for each sim_type
    for pair_id in sentence_pair_parsed_dict_mod.keys():
        
        # Get the sentence pair to compute similarity for
        sentence_pair = sentence_pair_parsed_dict_mod[pair_id]
        sent_1_parsed = sentence_pair[0]
        sent_2_parsed = sentence_pair[1]
        
        # Define data storage structures
        sent_1_tags = [role for role in sent_1_parsed.keys() if sent_1_parsed[role] != 'NONE'] # ignore roles with NONE value
        sent_2_tags = [role for role in sent_2_parsed.keys() if sent_2_parsed[role] != 'NONE']
        all_sent_tags = set(list(sent_1_tags)+list(sent_2_tags))
        role_sim_storage[pair_id] = {}
        
        # Loop over all role tags and store similarities for paired phrases
        for role_tag in sent_1_parsed.keys(): # loop over all tags found in either sentence
            if (role_tag in sent_1_tags) and (role_tag in sent_2_tags): # only if both sentences have the same tag
                
                # get phrases for given role tag
                phrase_1 = sent_1_parsed[role_tag].lower()
                phrase_2 = sent_2_parsed[role_tag].lower()
                
                # compute different types of similarities for phrase pairs of given role tag
                if sim_type=='sentbert':
                    role_sim_storage[pair_id][role_tag] = float(sentbert_sim([phrase_1, phrase_2])[0]) # conversion to float needed for saving to .json, as it doesn't like numpy format
                elif sim_type=='conceptnet':
                    role_sim_storage[pair_id][role_tag] = float(calc_weighted_phrase_sim(pair_id, phrase_1, phrase_2, weighting=False))
                elif sim_type=='conceptnet_wtd':
                    role_sim_storage[pair_id][role_tag] = float(calc_weighted_phrase_sim(pair_id, phrase_1, phrase_2, weighting=True))
                elif sim_type=='hybrid_1' or sim_type=='hybrid_2':
                    role_sim_storage[pair_id][role_tag] = float(calc_hybrid_phrase_sim(pair_id, phrase_1, phrase_2, weighting=True, cutoff=1))
                
            else:
                role_sim_storage[pair_id][role_tag] = np.NaN # if the tag doesn't have a match

        # Make adjustments for non-identical tags needing to be compared
        for tag_pair in tag_alignment_dict: # loop over list of tag pairs to combine
            role_sim_storage[pair_id] = align_tags(role_sim_storage[pair_id], sentence_pair_parsed_dict_mod, pair_id, tag_pair[0], tag_pair[1], sent_1_tags, sent_2_tags, sim_type, cutoff=1)
    
        # Convert dictionary storage of rolewise sims into list
        sim_storage_list = dict_sim_to_list(role_weights_dict,role_sim_storage[pair_id])
        
        # Compute overall similarity for given sentence
        try:
            masked_sim_list = np.ma.MaskedArray(sim_storage_list, mask=np.isnan(sim_storage_list)) # get masked array to remove nans
            # print(pair_id, masked_sim_list)
            overall_verbnet_sim = np.ma.average(masked_sim_list, weights=role_weights_list)
        except ZeroDivisionError:
            overall_verbnet_sim = 0
            
        # Store VerbNet similarity for given sentence
        sim_storage_dict[sim_type] = np.append(sim_storage_dict[sim_type],overall_verbnet_sim)
    
    # Store role sims dictionary
    all_role_sim_storage_dict[sim_type] = role_sim_storage
# Out:
# 82 couldn't find seventhlargest
# 101 couldn't find vehicle_related
# 283 couldn't find two_bladed
# 464 couldn't find seventhlargest
# 627 couldn't find redbrown
# 630 couldn't find felttipped
# 665 couldn't find two_bladed
# 845 couldn't find seventhlargest
# 864 couldn't find vehicle_related
# 978 couldn't find highpitched
# 1008 couldn't find redbrown
# 1011 couldn't find felttipped
# 1046 couldn't find two_bladed
# 1225 couldn't find seventhlargest
# 1388 couldn't find redbrown
# 1391 couldn't find felttipped
# 1426 couldn't find two_bladed
# 1551 couldn't find airbeds
# 1604 couldn't find seventhlargest
# 1623 couldn't find vehicle_related
# 1770 couldn't find felttipped
# 1805 couldn't find two_bladed
# 1982 couldn't find seventhlargest
# 2145 couldn't find redbrown
# 2148 couldn't find felttipped
# 2183 couldn't find two_bladed
# 2359 couldn't find seventhlargest
# 2378 couldn't find vehicle_related
# 2560 couldn't find two_bladed
# 2735 couldn't find seventhlargest
# 2898 couldn't find redbrown
# 2901 couldn't find felttipped
# 2936 couldn't find two_bladed
# 3110 couldn't find seventhlargest
# 3129 couldn't find vehicle_related
# 3311 couldn't find two_bladed
# 3431 couldn't find airbeds
# 3484 couldn't find seventhlargest
# 3647 couldn't find redbrown
# 3650 couldn't find felttipped
# 3685 couldn't find two_bladed
# 3857 couldn't find seventhlargest
# 4020 couldn't find redbrown
# 4023 couldn't find felttipped
# 4058 couldn't find two_bladed
# 4229 couldn't find seventhlargest
# 4248 couldn't find vehicle_related
# 4362 couldn't find highpitched
# 4392 couldn't find redbrown
# 4395 couldn't find felttipped
# 4430 couldn't find two_bladed
# 4600 couldn't find seventhlargest
# 4619 couldn't find vehicle_related
# 4801 couldn't find two_bladed
# 4970 couldn't find seventhlargest
# 5133 couldn't find redbrown
# 5136 couldn't find felttipped
# 5171 couldn't find two_bladed
# 5339 couldn't find seventhlargest
# 5358 couldn't find vehicle_related
# 5472 couldn't find highpitched
# 5502 couldn't find redbrown
# 5505 couldn't find felttipped
# 5540 couldn't find two_bladed
# 5707 couldn't find seventhlargest
# 5726 couldn't find vehicle_related
# 5908 couldn't find two_bladed
# 6074 couldn't find seventhlargest
# 6093 couldn't find vehicle_related
# 6275 couldn't find two_bladed
# 6440 couldn't find seventhlargest
# 6603 couldn't find redbrown
# 6606 couldn't find felttipped
# 6641 couldn't find two_bladed
# 6752 couldn't find airbeds
# 6805 couldn't find seventhlargest
# 6968 couldn't find redbrown
# 6971 couldn't find felttipped
# 7006 couldn't find two_bladed
# 7169 couldn't find seventhlargest
# 7188 couldn't find vehicle_related
# 7370 couldn't find two_bladed
# 7532 couldn't find seventhlargest
# 7551 couldn't find vehicle_related
# 7733 couldn't find two_bladed
# 7894 couldn't find seventhlargest
# 7913 couldn't find vehicle_related
# 8095 couldn't find two_bladed
# 8255 couldn't find seventhlargest
# 8418 couldn't find redbrown
# 8421 couldn't find felttipped
# 8456 couldn't find two_bladed
# 8562 couldn't find airbeds
# 8615 couldn't find seventhlargest
# 8615 couldn't find seventhlargest
# 8634 couldn't find vehicle_related
# 8748 couldn't find highpitched
# 8778 couldn't find redbrown
# 8781 couldn't find felttipped
# 8816 couldn't find two_bladed
# 8816 couldn't find two_bladed
# 8974 couldn't find seventhlargest
# 8993 couldn't find vehicle_related
# 9175 couldn't find two_bladed
# 9332 couldn't find seventhlargest
# 9351 couldn't find vehicle_related
# 9533 couldn't find two_bladed
# 9689 couldn't find seventhlargest
# 9708 couldn't find vehicle_related
# 9890 couldn't find two_bladed
# 9992 couldn't find airbeds
# 10045 couldn't find seventhlargest
# 10064 couldn't find vehicle_related
# 10178 couldn't find highpitched
# 10208 couldn't find redbrown
# 10211 couldn't find felttipped
# 10246 couldn't find two_bladed
# 10330 couldn't find 70
# 10347 couldn't find airbeds
# 10400 couldn't find seventhlargest
# 10419 couldn't find vehicle_related
# 10566 couldn't find felttipped
# 10601 couldn't find two_bladed
# 10754 couldn't find seventhlargest
# 10773 couldn't find vehicle_related
# 10887 couldn't find highpitched
# 10917 couldn't find redbrown
# 10920 couldn't find felttipped
# 10955 couldn't find two_bladed
# 11055 couldn't find airbeds
# 11057 couldn't find airbeds
# 11058 couldn't find airbeds
# 11061 couldn't find airbeds
# 11065 couldn't find airbeds
# 11069 couldn't find airbeds
# 11076 couldn't find airbeds
# 11092 couldn't find airbeds
# 11095 couldn't find airbeds
# 11099 couldn't find airbeds
# 11102 couldn't find airbeds
# 11105 couldn't find airbeds
# 11107 couldn't find seventhlargest
# 11108 couldn't find airbeds
# 11110 couldn't find airbeds
# 11111 couldn't find airbeds
# 11112 couldn't find airbeds
# 11116 couldn't find airbeds
# 11122 couldn't find airbeds
# 11123 couldn't find airbeds
# 11125 couldn't find airbeds
# 11128 couldn't find airbeds
# 11130 couldn't find airbeds
# 11131 couldn't find airbeds
# 11134 couldn't find airbeds
# 11135 couldn't find airbeds
# 11136 couldn't find airbeds
# 11138 couldn't find airbeds
# 11139 couldn't find airbeds
# 11142 couldn't find airbeds
# 11147 couldn't find airbeds
# 11151 couldn't find airbeds
# 11152 couldn't find airbeds
# 11157 couldn't find airbeds
# 11158 couldn't find airbeds
# 11160 couldn't find airbeds
# 11162 couldn't find airbeds
# 11163 couldn't find airbeds
# 11164 couldn't find airbeds
# 11166 couldn't find airbeds
# 11169 couldn't find airbeds
# 11174 couldn't find airbeds
# 11178 couldn't find airbeds
# 11184 couldn't find airbeds
# 11186 couldn't find airbeds
# 11189 couldn't find airbeds
# 11192 couldn't find airbeds
# 11194 couldn't find airbeds
# 11195 couldn't find airbeds
# 11197 couldn't find airbeds
# 11200 couldn't find airbeds
# 11202 couldn't find airbeds
# 11204 couldn't find airbeds
# 11207 couldn't find airbeds
# 11208 couldn't find airbeds
# 11209 couldn't find airbeds
# 11211 couldn't find airbeds
# 11218 couldn't find airbeds
# 11220 couldn't find airbeds
# 11221 couldn't find airbeds
# 11222 couldn't find airbeds
# 11224 couldn't find airbeds
# 11225 couldn't find airbeds
# 11226 couldn't find airbeds
# 11228 couldn't find airbeds
# 11244 couldn't find airbeds
# 11245 couldn't find airbeds
# 11248 couldn't find airbeds
# 11251 couldn't find airbeds
# 11255 couldn't find airbeds
# 11257 couldn't find airbeds
# 11260 couldn't find airbeds
# 11263 couldn't find airbeds
# 11264 couldn't find airbeds
# 11270 couldn't find redbrown
# 11270 couldn't find airbeds
# 11273 couldn't find felttipped
# 11273 couldn't find airbeds
# 11274 couldn't find airbeds
# 11276 couldn't find airbeds
# 11277 couldn't find airbeds
# 11282 couldn't find airbeds
# 11283 couldn't find airbeds
# 11284 couldn't find airbeds
# 11287 couldn't find airbeds
# 11288 couldn't find airbeds
# 11289 couldn't find airbeds
# 11291 couldn't find airbeds
# 11292 couldn't find airbeds
# 11293 couldn't find airbeds
# 11294 couldn't find airbeds
# 11296 couldn't find airbeds
# 11303 couldn't find airbeds
# 11307 couldn't find airbeds
# 11308 couldn't find airbeds
# 11308 couldn't find two_bladed
# 11312 couldn't find airbeds
# 11313 couldn't find airbeds
# 11320 couldn't find airbeds
# 11321 couldn't find airbeds
# 11322 couldn't find airbeds
# 11323 couldn't find airbeds
# 11330 couldn't find airbeds
# 11332 couldn't find airbeds
# 11344 couldn't find airbeds
# 11349 couldn't find airbeds
# 11350 couldn't find airbeds
# 11351 couldn't find airbeds
# 11355 couldn't find airbeds
# 11361 couldn't find airbeds
# 11362 couldn't find airbeds
# 11365 couldn't find airbeds
# 11368 couldn't find airbeds
# 11370 couldn't find airbeds
# 11371 couldn't find airbeds
# 11372 couldn't find airbeds
# 11374 couldn't find airbeds
# 11375 couldn't find airbeds
# 11376 couldn't find airbeds
# 11379 couldn't find airbeds
# 11382 couldn't find airbeds
# 11386 couldn't find airbeds
# 11392 couldn't find airbeds
# 11395 couldn't find airbeds
# 11396 couldn't find airbeds
# 11397 couldn't find airbeds
# 11400 couldn't find airbeds
# 11401 couldn't find airbeds
# 11402 couldn't find airbeds
# 11403 couldn't find airbeds
# 11407 couldn't find airbeds
# 11459 couldn't find seventhlargest
# 11478 couldn't find vehicle_related
# 11592 couldn't find highpitched
# 11622 couldn't find redbrown
# 11625 couldn't find felttipped
# 11660 couldn't find two_bladed
# 11744 couldn't find 70
# 11810 couldn't find seventhlargest
# 11829 couldn't find vehicle_related
# 12011 couldn't find two_bladed
# 12160 couldn't find seventhlargest
# 12179 couldn't find vehicle_related
# 12293 couldn't find highpitched
# 12323 couldn't find redbrown
# 12326 couldn't find felttipped
# 12361 couldn't find two_bladed
# 12445 couldn't find 70
# 12509 couldn't find seventhlargest
# 12528 couldn't find vehicle_related
# 12675 couldn't find felttipped
# 12710 couldn't find two_bladed
# 12857 couldn't find seventhlargest
# 13020 couldn't find redbrown
# 13023 couldn't find felttipped
# 13058 couldn't find two_bladed
# 13204 couldn't find seventhlargest
# 13223 couldn't find vehicle_related
# 13405 couldn't find two_bladed
# 13550 couldn't find seventhlargest
# 13713 couldn't find redbrown
# 13716 couldn't find felttipped
# 13751 couldn't find two_bladed
# 13895 couldn't find seventhlargest
# 13914 couldn't find vehicle_related
# 14028 couldn't find highpitched
# 14058 couldn't find redbrown
# 14061 couldn't find felttipped
# 14096 couldn't find two_bladed
# 14239 couldn't find seventhlargest
# 14258 couldn't find vehicle_related
# 14372 couldn't find highpitched
# 14402 couldn't find redbrown
# 14405 couldn't find felttipped
# 14440 couldn't find two_bladed
# 14582 couldn't find seventhlargest
# 14601 couldn't find vehicle_related
# 14715 couldn't find highpitched
# 14745 couldn't find redbrown
# 14748 couldn't find felttipped
# 14783 couldn't find two_bladed
# 14867 couldn't find 70
# 14924 couldn't find seventhlargest
# 14943 couldn't find vehicle_related
# 15057 couldn't find highpitched
# 15057 couldn't find highpitched
# 15087 couldn't find redbrown
# 15090 couldn't find felttipped
# 15125 couldn't find two_bladed
# 15209 couldn't find 70
# 15265 couldn't find seventhlargest
# 15428 couldn't find redbrown
# 15431 couldn't find felttipped
# 15466 couldn't find two_bladed
# 15605 couldn't find seventhlargest
# 15624 couldn't find vehicle_related
# 15738 couldn't find highpitched
# 15768 couldn't find redbrown
# 15771 couldn't find felttipped
# 15806 couldn't find two_bladed
# 15944 couldn't find seventhlargest
# 15963 couldn't find vehicle_related
# 16145 couldn't find two_bladed
# 16282 couldn't find seventhlargest
# 16301 couldn't find vehicle_related
# 16415 couldn't find highpitched
# 16445 couldn't find redbrown
# 16448 couldn't find felttipped
# 16483 couldn't find two_bladed
# 16619 couldn't find seventhlargest
# 16782 couldn't find redbrown
# 16785 couldn't find felttipped
# 16820 couldn't find two_bladed
# 16955 couldn't find seventhlargest
# 16974 couldn't find vehicle_related
# 17088 couldn't find highpitched
# 17118 couldn't find redbrown
# 17121 couldn't find felttipped
# 17156 couldn't find two_bladed
# 17240 couldn't find 70
# 17290 couldn't find seventhlargest
# 17309 couldn't find vehicle_related
# 17491 couldn't find two_bladed
# 17624 couldn't find seventhlargest
# 17643 couldn't find vehicle_related
# 17825 couldn't find two_bladed
# 17957 couldn't find seventhlargest
# 17976 couldn't find vehicle_related
# 18090 couldn't find highpitched
# 18120 couldn't find redbrown
# 18123 couldn't find felttipped
# 18158 couldn't find two_bladed
# 18242 couldn't find 70
# 18289 couldn't find seventhlargest
# 18308 couldn't find vehicle_related
# 18490 couldn't find two_bladed
# 18620 couldn't find seventhlargest
# 18639 couldn't find vehicle_related
# 18786 couldn't find felttipped
# 18821 couldn't find two_bladed
# 18950 couldn't find seventhlargest
# 19113 couldn't find redbrown
# 19116 couldn't find felttipped
# 19151 couldn't find two_bladed
# 19279 couldn't find seventhlargest
# 19298 couldn't find vehicle_related
# 19480 couldn't find two_bladed
# 19607 couldn't find seventhlargest
# 19626 couldn't find vehicle_related
# 19808 couldn't find two_bladed
# 19934 couldn't find seventhlargest
# 19953 couldn't find vehicle_related
# 20135 couldn't find two_bladed
# 20260 couldn't find seventhlargest
# 20279 couldn't find vehicle_related
# 20461 couldn't find two_bladed
# 20585 couldn't find seventhlargest
# 20604 couldn't find vehicle_related
# 20786 couldn't find two_bladed
# 20909 couldn't find seventhlargest
# 20928 couldn't find vehicle_related
# 21042 couldn't find highpitched
# 21072 couldn't find redbrown
# 21075 couldn't find felttipped
# 21110 couldn't find two_bladed
# 21232 couldn't find seventhlargest
# 21251 couldn't find vehicle_related
# 21433 couldn't find two_bladed
# 21554 couldn't find seventhlargest
# 21717 couldn't find redbrown
# 21720 couldn't find felttipped
# 21755 couldn't find two_bladed
# 21875 couldn't find seventhlargest
# 21894 couldn't find vehicle_related
# 22008 couldn't find highpitched
# 22038 couldn't find redbrown
# 22041 couldn't find felttipped
# 22076 couldn't find two_bladed
# 22195 couldn't find seventhlargest
# 22214 couldn't find vehicle_related
# 22328 couldn't find highpitched
# 22358 couldn't find redbrown
# 22361 couldn't find felttipped
# 22396 couldn't find two_bladed
# 22514 couldn't find seventhlargest
# 22533 couldn't find vehicle_related
# 22715 couldn't find two_bladed
# 22832 couldn't find seventhlargest
# 22851 couldn't find vehicle_related
# 22965 couldn't find highpitched
# 22995 couldn't find redbrown
# 22998 couldn't find felttipped
# 23033 couldn't find two_bladed
# 23117 couldn't find 70
# 23149 couldn't find seventhlargest
# 23149 couldn't find seventhlargest
# 23168 couldn't find vehicle_related
# 23282 couldn't find highpitched
# 23312 couldn't find redbrown
# 23315 couldn't find felttipped
# 23350 couldn't find two_bladed
# 23350 couldn't find two_bladed
# 23465 couldn't find seventhlargest
# 23484 couldn't find vehicle_related
# 23598 couldn't find highpitched
# 23628 couldn't find redbrown
# 23631 couldn't find felttipped
# 23666 couldn't find two_bladed
# 23750 couldn't find 70
# 23780 couldn't find seventhlargest
# 23799 couldn't find vehicle_related
# 23913 couldn't find highpitched
# 23943 couldn't find redbrown
# 23946 couldn't find felttipped
# 23981 couldn't find two_bladed
# 24065 couldn't find 70
# 24094 couldn't find seventhlargest
# 24113 couldn't find vehicle_related
# 24295 couldn't find two_bladed
# 24407 couldn't find seventhlargest
# 24407 couldn't find seventhlargest
# 24426 couldn't find vehicle_related
# 24540 couldn't find highpitched
# 24570 couldn't find redbrown
# 24573 couldn't find felttipped
# 24608 couldn't find two_bladed
# 24608 couldn't find two_bladed
# 24719 couldn't find seventhlargest
# 24738 couldn't find vehicle_related
# 24885 couldn't find felttipped
# 24920 couldn't find two_bladed
# 25030 couldn't find seventhlargest
# 25049 couldn't find vehicle_related
# 25231 couldn't find two_bladed
# 25340 couldn't find seventhlargest
# 25359 couldn't find vehicle_related
# 25541 couldn't find two_bladed
# 25649 couldn't find seventhlargest
# 25649 couldn't find seventhlargest
# 25668 couldn't find vehicle_related
# 25782 couldn't find highpitched
# 25812 couldn't find redbrown
# 25815 couldn't find felttipped
# 25850 couldn't find two_bladed
# 25850 couldn't find two_bladed
# 25957 couldn't find seventhlargest
# 25976 couldn't find vehicle_related
# 26090 couldn't find highpitched
# 26123 couldn't find felttipped
# 26158 couldn't find two_bladed
# 26264 couldn't find seventhlargest
# 26283 couldn't find vehicle_related
# 26465 couldn't find two_bladed
# 26570 couldn't find seventhlargest
# 26589 couldn't find vehicle_related
# 26771 couldn't find two_bladed
# 26875 couldn't find seventhlargest
# 27008 couldn't find highpitched
# 27038 couldn't find redbrown
# 27041 couldn't find felttipped
# 27076 couldn't find two_bladed
# 27160 couldn't find 70
# 27482 couldn't find seventhlargest
# 27501 couldn't find vehicle_related
# 27615 couldn't find highpitched
# 27645 couldn't find redbrown
# 27648 couldn't find felttipped
# 27683 couldn't find two_bladed
# 27784 couldn't find seventhlargest
# 27803 couldn't find vehicle_related
# 27917 couldn't find highpitched
# 27947 couldn't find redbrown
# 27950 couldn't find felttipped
# 27950 couldn't find felttipped
# 27985 couldn't find two_bladed
# 28069 couldn't find 70
# 28085 couldn't find seventhlargest
# 28248 couldn't find redbrown
# 28251 couldn't find felttipped
# 28286 couldn't find two_bladed
# 28386 couldn't find seventhlargest
# 28387 couldn't find seventhlargest
# 28389 couldn't find seventhlargest
# 28390 couldn't find seventhlargest
# 28391 couldn't find seventhlargest
# 28392 couldn't find seventhlargest
# 28393 couldn't find seventhlargest
# 28394 couldn't find seventhlargest
# 28395 couldn't find seventhlargest
# 28396 couldn't find seventhlargest
# 28397 couldn't find seventhlargest
# 28398 couldn't find seventhlargest
# 28399 couldn't find seventhlargest
# 28400 couldn't find seventhlargest
# 28401 couldn't find seventhlargest
# 28402 couldn't find seventhlargest
# 28403 couldn't find seventhlargest
# 28404 couldn't find seventhlargest
# 28404 couldn't find vehicle_related
# 28405 couldn't find seventhlargest
# 28406 couldn't find seventhlargest
# 28407 couldn't find seventhlargest
# 28408 couldn't find seventhlargest
# 28410 couldn't find seventhlargest
# 28411 couldn't find seventhlargest
# 28413 couldn't find seventhlargest
# 28414 couldn't find seventhlargest
# 28415 couldn't find seventhlargest
# 28415 couldn't find seventhlargest
# 28416 couldn't find seventhlargest
# 28417 couldn't find seventhlargest
# 28418 couldn't find seventhlargest
# 28419 couldn't find seventhlargest
# 28420 couldn't find seventhlargest
# 28421 couldn't find seventhlargest
# 28422 couldn't find seventhlargest
# 28423 couldn't find seventhlargest
# 28424 couldn't find seventhlargest
# 28425 couldn't find seventhlargest
# 28426 couldn't find seventhlargest
# 28427 couldn't find seventhlargest
# 28428 couldn't find seventhlargest
# 28429 couldn't find seventhlargest
# 28430 couldn't find seventhlargest
# 28431 couldn't find seventhlargest
# 28432 couldn't find seventhlargest
# 28433 couldn't find seventhlargest
# 28434 couldn't find seventhlargest
# 28435 couldn't find seventhlargest
# 28436 couldn't find seventhlargest
# 28437 couldn't find seventhlargest
# 28438 couldn't find seventhlargest
# 28439 couldn't find seventhlargest
# 28440 couldn't find seventhlargest
# 28440 couldn't find seventhlargest
# 28441 couldn't find seventhlargest
# 28442 couldn't find seventhlargest
# 28443 couldn't find seventhlargest
# 28443 couldn't find seventhlargest
# 28444 couldn't find seventhlargest
# 28445 couldn't find seventhlargest
# 28446 couldn't find seventhlargest
# 28447 couldn't find seventhlargest
# 28448 couldn't find seventhlargest
# 28449 couldn't find seventhlargest
# 28450 couldn't find seventhlargest
# 28451 couldn't find seventhlargest
# 28452 couldn't find seventhlargest
# 28453 couldn't find seventhlargest
# 28454 couldn't find seventhlargest
# 28455 couldn't find seventhlargest
# 28457 couldn't find seventhlargest
# 28458 couldn't find seventhlargest
# 28459 couldn't find seventhlargest
# 28460 couldn't find seventhlargest
# 28460 couldn't find seventhlargest
# 28461 couldn't find seventhlargest
# 28462 couldn't find seventhlargest
# 28463 couldn't find seventhlargest
# 28464 couldn't find seventhlargest
# 28465 couldn't find seventhlargest
# 28466 couldn't find seventhlargest
# 28467 couldn't find seventhlargest
# 28468 couldn't find seventhlargest
# 28469 couldn't find seventhlargest
# 28470 couldn't find seventhlargest
# 28471 couldn't find seventhlargest
# 28472 couldn't find seventhlargest
# 28473 couldn't find seventhlargest
# 28474 couldn't find seventhlargest
# 28475 couldn't find seventhlargest
# 28475 couldn't find seventhlargest
# 28476 couldn't find seventhlargest
# 28477 couldn't find seventhlargest
# 28477 couldn't find seventhlargest
# 28478 couldn't find seventhlargest
# 28479 couldn't find seventhlargest
# 28480 couldn't find seventhlargest
# 28481 couldn't find seventhlargest
# 28482 couldn't find seventhlargest
# 28483 couldn't find seventhlargest
# 28484 couldn't find seventhlargest
# 28485 couldn't find seventhlargest
# 28486 couldn't find seventhlargest
# 28487 couldn't find seventhlargest
# 28488 couldn't find seventhlargest
# 28489 couldn't find seventhlargest
# 28490 couldn't find seventhlargest
# 28491 couldn't find seventhlargest
# 28492 couldn't find seventhlargest
# 28493 couldn't find seventhlargest
# 28494 couldn't find seventhlargest
# 28495 couldn't find seventhlargest
# 28496 couldn't find seventhlargest
# 28497 couldn't find seventhlargest
# 28498 couldn't find seventhlargest
# 28499 couldn't find seventhlargest
# 28500 couldn't find seventhlargest
# 28501 couldn't find seventhlargest
# 28502 couldn't find seventhlargest
# 28504 couldn't find seventhlargest
# 28505 couldn't find seventhlargest
# 28506 couldn't find seventhlargest
# 28507 couldn't find seventhlargest
# 28508 couldn't find seventhlargest
# 28509 couldn't find seventhlargest
# 28509 couldn't find seventhlargest
# 28510 couldn't find seventhlargest
# 28511 couldn't find seventhlargest
# 28512 couldn't find seventhlargest
# 28513 couldn't find seventhlargest
# 28514 couldn't find seventhlargest
# 28515 couldn't find seventhlargest
# 28516 couldn't find seventhlargest
# 28517 couldn't find seventhlargest
# 28518 couldn't find seventhlargest
# 28519 couldn't find seventhlargest
# 28520 couldn't find seventhlargest
# 28521 couldn't find seventhlargest
# 28522 couldn't find seventhlargest
# 28523 couldn't find seventhlargest
# 28524 couldn't find seventhlargest
# 28525 couldn't find seventhlargest
# 28526 couldn't find seventhlargest
# 28527 couldn't find seventhlargest
# 28528 couldn't find seventhlargest
# 28529 couldn't find seventhlargest
# 28530 couldn't find seventhlargest
# 28531 couldn't find seventhlargest
# 28532 couldn't find seventhlargest
# 28533 couldn't find seventhlargest
# 28534 couldn't find seventhlargest
# 28535 couldn't find seventhlargest
# 28536 couldn't find seventhlargest
# 28537 couldn't find seventhlargest
# 28538 couldn't find seventhlargest
# 28539 couldn't find seventhlargest
# 28540 couldn't find seventhlargest
# 28541 couldn't find seventhlargest
# 28542 couldn't find seventhlargest
# 28543 couldn't find seventhlargest
# 28544 couldn't find seventhlargest
# 28544 couldn't find seventhlargest
# 28545 couldn't find seventhlargest
# 28546 couldn't find seventhlargest
# 28547 couldn't find seventhlargest
# 28548 couldn't find seventhlargest
# 28549 couldn't find seventhlargest
# 28550 couldn't find seventhlargest
# 28551 couldn't find seventhlargest
# 28552 couldn't find seventhlargest
# 28553 couldn't find seventhlargest
# 28554 couldn't find seventhlargest
# 28556 couldn't find seventhlargest
# 28556 couldn't find seventhlargest
# 28557 couldn't find seventhlargest
# 28558 couldn't find seventhlargest
# 28559 couldn't find seventhlargest
# 28560 couldn't find seventhlargest
# 28561 couldn't find seventhlargest
# 28562 couldn't find seventhlargest
# 28563 couldn't find seventhlargest
# 28564 couldn't find seventhlargest
# 28565 couldn't find seventhlargest
# 28566 couldn't find seventhlargest
# 28567 couldn't find seventhlargest
# 28568 couldn't find seventhlargest
# 28569 couldn't find seventhlargest
# 28570 couldn't find seventhlargest
# 28571 couldn't find seventhlargest
# 28572 couldn't find seventhlargest
# 28573 couldn't find seventhlargest
# 28574 couldn't find seventhlargest
# 28575 couldn't find seventhlargest
# 28576 couldn't find seventhlargest
# 28577 couldn't find seventhlargest
# 28578 couldn't find seventhlargest
# 28579 couldn't find seventhlargest
# 28580 couldn't find seventhlargest
# 28581 couldn't find seventhlargest
# 28582 couldn't find seventhlargest
# 28583 couldn't find seventhlargest
# 28584 couldn't find seventhlargest
# 28585 couldn't find seventhlargest
# 28586 couldn't find seventhlargest
# 28586 couldn't find two_bladed
# 28587 couldn't find seventhlargest
# 28588 couldn't find seventhlargest
# 28588 couldn't find seventhlargest
# 28589 couldn't find seventhlargest
# 28590 couldn't find seventhlargest
# 28591 couldn't find seventhlargest
# 28591 couldn't find seventhlargest
# 28592 couldn't find seventhlargest
# 28593 couldn't find seventhlargest
# 28594 couldn't find seventhlargest
# 28595 couldn't find seventhlargest
# 28596 couldn't find seventhlargest
# 28596 couldn't find seventhlargest
# 28597 couldn't find seventhlargest
# 28598 couldn't find seventhlargest
# 28599 couldn't find seventhlargest
# 28600 couldn't find seventhlargest
# 28601 couldn't find seventhlargest
# 28602 couldn't find seventhlargest
# 28603 couldn't find seventhlargest
# 28603 couldn't find seventhlargest
# 28604 couldn't find seventhlargest
# 28605 couldn't find seventhlargest
# 28606 couldn't find seventhlargest
# 28607 couldn't find seventhlargest
# 28607 couldn't find seventhlargest
# 28608 couldn't find seventhlargest
# 28609 couldn't find seventhlargest
# 28610 couldn't find seventhlargest
# 28611 couldn't find seventhlargest
# 28612 couldn't find seventhlargest
# 28613 couldn't find seventhlargest
# 28614 couldn't find seventhlargest
# 28615 couldn't find seventhlargest
# 28616 couldn't find seventhlargest
# 28617 couldn't find seventhlargest
# 28618 couldn't find seventhlargest
# 28619 couldn't find seventhlargest
# 28620 couldn't find seventhlargest
# 28621 couldn't find seventhlargest
# 28622 couldn't find seventhlargest
# 28623 couldn't find seventhlargest
# 28624 couldn't find seventhlargest
# 28625 couldn't find seventhlargest
# 28626 couldn't find seventhlargest
# 28627 couldn't find seventhlargest
# 28628 couldn't find seventhlargest
# 28629 couldn't find seventhlargest
# 28630 couldn't find seventhlargest
# 28631 couldn't find seventhlargest
# 28632 couldn't find seventhlargest
# 28633 couldn't find seventhlargest
# 28634 couldn't find seventhlargest
# 28635 couldn't find seventhlargest
# 28636 couldn't find seventhlargest
# 28637 couldn't find seventhlargest
# 28638 couldn't find seventhlargest
# 28639 couldn't find seventhlargest
# 28640 couldn't find seventhlargest
# 28641 couldn't find seventhlargest
# 28642 couldn't find seventhlargest
# 28643 couldn't find seventhlargest
# 28644 couldn't find seventhlargest
# 28645 couldn't find seventhlargest
# 28646 couldn't find seventhlargest
# 28647 couldn't find seventhlargest
# 28647 couldn't find seventhlargest
# 28648 couldn't find seventhlargest
# 28649 couldn't find seventhlargest
# 28650 couldn't find seventhlargest
# 28651 couldn't find seventhlargest
# 28652 couldn't find seventhlargest
# 28654 couldn't find seventhlargest
# 28655 couldn't find seventhlargest
# 28656 couldn't find seventhlargest
# 28657 couldn't find seventhlargest
# 28658 couldn't find seventhlargest
# 28659 couldn't find seventhlargest
# 28660 couldn't find seventhlargest
# 28661 couldn't find seventhlargest
# 28661 couldn't find seventhlargest
# 28662 couldn't find seventhlargest
# 28663 couldn't find seventhlargest
# 28664 couldn't find seventhlargest
# 28665 couldn't find seventhlargest
# 28666 couldn't find seventhlargest
# 28667 couldn't find seventhlargest
# 28668 couldn't find seventhlargest
# 28669 couldn't find seventhlargest
# 28670 couldn't find seventhlargest
# 28671 couldn't find seventhlargest
# 28672 couldn't find seventhlargest
# 28673 couldn't find seventhlargest
# 28674 couldn't find seventhlargest
# 28675 couldn't find seventhlargest
# 28676 couldn't find seventhlargest
# 28677 couldn't find seventhlargest
# 28678 couldn't find seventhlargest
# 28679 couldn't find seventhlargest
# 28680 couldn't find seventhlargest
# 28681 couldn't find seventhlargest
# 28682 couldn't find seventhlargest
# 28683 couldn't find seventhlargest
# 28684 couldn't find seventhlargest
# 28685 couldn't find seventhlargest
# 28703 couldn't find vehicle_related
# 28817 couldn't find highpitched
# 28847 couldn't find redbrown
# 28850 couldn't find felttipped
# 28850 couldn't find felttipped
# 28885 couldn't find two_bladed
# 28969 couldn't find 70
# 29001 couldn't find vehicle_related
# 29115 couldn't find highpitched
# 29145 couldn't find redbrown
# 29148 couldn't find felttipped
# 29183 couldn't find two_bladed
# 29267 couldn't find 70
# 29445 couldn't find felttipped
# 29594 couldn't find vehicle_related
# 29741 couldn't find felttipped
# 29776 couldn't find two_bladed
# 29889 couldn't find vehicle_related
# 30036 couldn't find felttipped
# 30071 couldn't find two_bladed
# 30327 couldn't find redbrown
# 30330 couldn't find felttipped
# 30365 couldn't find two_bladed
# 30476 couldn't find vehicle_related
# 30590 couldn't find highpitched
# 30620 couldn't find redbrown
# 30623 couldn't find felttipped
# 30658 couldn't find two_bladed
# 30768 couldn't find vehicle_related
# 30950 couldn't find two_bladed
# 31059 couldn't find vehicle_related
# 31206 couldn't find felttipped
# 31241 couldn't find two_bladed
# 31349 couldn't find vehicle_related
# 31463 couldn't find highpitched
# 31493 couldn't find redbrown
# 31496 couldn't find felttipped
# 31531 couldn't find two_bladed
# 31782 couldn't find redbrown
# 31785 couldn't find felttipped
# 31820 couldn't find two_bladed
# 31926 couldn't find vehicle_related
# 32108 couldn't find two_bladed
# 32213 couldn't find vehicle_related
# 32395 couldn't find two_bladed
# 32499 couldn't find vehicle_related
# 32681 couldn't find two_bladed
# 32784 couldn't find vehicle_related
# 32931 couldn't find felttipped
# 32966 couldn't find two_bladed
# 33068 couldn't find vehicle_related
# 33182 couldn't find highpitched
# 33215 couldn't find felttipped
# 33250 couldn't find two_bladed
# 33334 couldn't find 70
# 33351 couldn't find vehicle_related
# 33533 couldn't find two_bladed
# 33633 couldn't find vehicle_related
# 33780 couldn't find felttipped
# 33815 couldn't find two_bladed
# 33915 couldn't find vehicle_related
# 33916 couldn't find vehicle_related
# 33917 couldn't find vehicle_related
# 33918 couldn't find vehicle_related
# 33920 couldn't find vehicle_related
# 33923 couldn't find vehicle_related
# 33924 couldn't find vehicle_related
# 33925 couldn't find vehicle_related
# 33927 couldn't find vehicle_related
# 33928 couldn't find vehicle_related
# 33929 couldn't find vehicle_related
# 33931 couldn't find vehicle_related
# 33932 couldn't find vehicle_related
# 33933 couldn't find vehicle_related
# 33934 couldn't find vehicle_related
# 33935 couldn't find vehicle_related
# 33936 couldn't find vehicle_related
# 33937 couldn't find vehicle_related
# 33939 couldn't find vehicle_related
# 33941 couldn't find vehicle_related
# 33942 couldn't find vehicle_related
# 33944 couldn't find vehicle_related
# 33945 couldn't find vehicle_related
# 33948 couldn't find vehicle_related
# 33950 couldn't find vehicle_related
# 33952 couldn't find vehicle_related
# 33953 couldn't find vehicle_related
# 33954 couldn't find vehicle_related
# 33955 couldn't find vehicle_related
# 33956 couldn't find vehicle_related
# 33957 couldn't find vehicle_related
# 33959 couldn't find vehicle_related
# 33960 couldn't find vehicle_related
# 33961 couldn't find vehicle_related
# 33963 couldn't find vehicle_related
# 33964 couldn't find vehicle_related
# 33965 couldn't find vehicle_related
# 33967 couldn't find vehicle_related
# 33968 couldn't find vehicle_related
# 33969 couldn't find vehicle_related
# 33970 couldn't find vehicle_related
# 33972 couldn't find vehicle_related
# 33973 couldn't find vehicle_related
# 33974 couldn't find vehicle_related
# 33975 couldn't find vehicle_related
# 33976 couldn't find vehicle_related
# 33977 couldn't find vehicle_related
# 33978 couldn't find vehicle_related
# 33979 couldn't find vehicle_related
# 33980 couldn't find vehicle_related
# 33981 couldn't find vehicle_related
# 33982 couldn't find vehicle_related
# 33984 couldn't find vehicle_related
# 33985 couldn't find vehicle_related
# 33986 couldn't find vehicle_related
# 33987 couldn't find vehicle_related
# 33988 couldn't find vehicle_related
# 33990 couldn't find vehicle_related
# 33992 couldn't find vehicle_related
# 33993 couldn't find vehicle_related
# 33994 couldn't find vehicle_related
# 33996 couldn't find vehicle_related
# 33997 couldn't find vehicle_related
# 33998 couldn't find vehicle_related
# 34000 couldn't find vehicle_related
# 34001 couldn't find vehicle_related
# 34002 couldn't find vehicle_related
# 34003 couldn't find vehicle_related
# 34004 couldn't find vehicle_related
# 34005 couldn't find vehicle_related
# 34006 couldn't find vehicle_related
# 34007 couldn't find vehicle_related
# 34008 couldn't find vehicle_related
# 34009 couldn't find vehicle_related
# 34010 couldn't find vehicle_related
# 34011 couldn't find vehicle_related
# 34012 couldn't find vehicle_related
# 34014 couldn't find vehicle_related
# 34015 couldn't find vehicle_related
# 34016 couldn't find vehicle_related
# 34017 couldn't find vehicle_related
# 34018 couldn't find vehicle_related
# 34019 couldn't find vehicle_related
# 34020 couldn't find vehicle_related
# 34022 couldn't find vehicle_related
# 34023 couldn't find vehicle_related
# 34024 couldn't find vehicle_related
# 34025 couldn't find vehicle_related
# 34027 couldn't find vehicle_related
# 34028 couldn't find vehicle_related
# 34028 couldn't find highpitched
# 34029 couldn't find vehicle_related
# 34030 couldn't find vehicle_related
# 34032 couldn't find vehicle_related
# 34033 couldn't find vehicle_related
# 34034 couldn't find vehicle_related
# 34035 couldn't find vehicle_related
# 34036 couldn't find vehicle_related
# 34037 couldn't find vehicle_related
# 34038 couldn't find vehicle_related
# 34039 couldn't find vehicle_related
# 34040 couldn't find vehicle_related
# 34041 couldn't find vehicle_related
# 34042 couldn't find vehicle_related
# 34043 couldn't find vehicle_related
# 34044 couldn't find vehicle_related
# 34045 couldn't find vehicle_related
# 34046 couldn't find vehicle_related
# 34047 couldn't find vehicle_related
# 34048 couldn't find vehicle_related
# 34049 couldn't find vehicle_related
# 34051 couldn't find vehicle_related
# 34052 couldn't find vehicle_related
# 34054 couldn't find vehicle_related
# 34055 couldn't find vehicle_related
# 34056 couldn't find vehicle_related
# 34057 couldn't find vehicle_related
# 34058 couldn't find redbrown
# 34058 couldn't find vehicle_related
# 34059 couldn't find vehicle_related
# 34060 couldn't find vehicle_related
# 34061 couldn't find felttipped
# 34061 couldn't find vehicle_related
# 34063 couldn't find vehicle_related
# 34064 couldn't find vehicle_related
# 34066 couldn't find vehicle_related
# 34068 couldn't find vehicle_related
# 34069 couldn't find vehicle_related
# 34070 couldn't find vehicle_related
# 34071 couldn't find vehicle_related
# 34072 couldn't find vehicle_related
# 34074 couldn't find vehicle_related
# 34075 couldn't find vehicle_related
# 34076 couldn't find vehicle_related
# 34078 couldn't find vehicle_related
# 34079 couldn't find vehicle_related
# 34080 couldn't find vehicle_related
# 34081 couldn't find vehicle_related
# 34082 couldn't find vehicle_related
# 34083 couldn't find vehicle_related
# 34084 couldn't find vehicle_related
# 34085 couldn't find vehicle_related
# 34086 couldn't find vehicle_related
# 34087 couldn't find vehicle_related
# 34088 couldn't find vehicle_related
# 34089 couldn't find vehicle_related
# 34090 couldn't find vehicle_related
# 34091 couldn't find vehicle_related
# 34092 couldn't find vehicle_related
# 34093 couldn't find vehicle_related
# 34094 couldn't find vehicle_related
# 34096 couldn't find vehicle_related
# 34096 couldn't find two_bladed
# 34097 couldn't find vehicle_related
# 34098 couldn't find vehicle_related
# 34099 couldn't find vehicle_related
# 34100 couldn't find vehicle_related
# 34101 couldn't find vehicle_related
# 34102 couldn't find vehicle_related
# 34103 couldn't find vehicle_related
# 34104 couldn't find vehicle_related
# 34106 couldn't find vehicle_related
# 34108 couldn't find vehicle_related
# 34109 couldn't find vehicle_related
# 34111 couldn't find vehicle_related
# 34112 couldn't find vehicle_related
# 34113 couldn't find vehicle_related
# 34115 couldn't find vehicle_related
# 34116 couldn't find vehicle_related
# 34117 couldn't find vehicle_related
# 34118 couldn't find vehicle_related
# 34119 couldn't find vehicle_related
# 34120 couldn't find vehicle_related
# 34121 couldn't find vehicle_related
# 34122 couldn't find vehicle_related
# 34123 couldn't find vehicle_related
# 34124 couldn't find vehicle_related
# 34125 couldn't find vehicle_related
# 34126 couldn't find vehicle_related
# 34127 couldn't find vehicle_related
# 34128 couldn't find vehicle_related
# 34129 couldn't find vehicle_related
# 34130 couldn't find vehicle_related
# 34131 couldn't find vehicle_related
# 34132 couldn't find vehicle_related
# 34133 couldn't find vehicle_related
# 34134 couldn't find vehicle_related
# 34135 couldn't find vehicle_related
# 34136 couldn't find vehicle_related
# 34138 couldn't find vehicle_related
# 34139 couldn't find vehicle_related
# 34140 couldn't find vehicle_related
# 34141 couldn't find vehicle_related
# 34143 couldn't find vehicle_related
# 34144 couldn't find vehicle_related
# 34145 couldn't find vehicle_related
# 34146 couldn't find vehicle_related
# 34148 couldn't find vehicle_related
# 34151 couldn't find vehicle_related
# 34152 couldn't find vehicle_related
# 34153 couldn't find vehicle_related
# 34156 couldn't find vehicle_related
# 34157 couldn't find vehicle_related
# 34160 couldn't find vehicle_related
# 34161 couldn't find vehicle_related
# 34164 couldn't find vehicle_related
# 34167 couldn't find vehicle_related
# 34168 couldn't find vehicle_related
# 34169 couldn't find vehicle_related
# 34171 couldn't find vehicle_related
# 34172 couldn't find vehicle_related
# 34173 couldn't find vehicle_related
# 34174 couldn't find vehicle_related
# 34176 couldn't find vehicle_related
# 34177 couldn't find vehicle_related
# 34178 couldn't find vehicle_related
# 34179 couldn't find vehicle_related
# 34180 couldn't find vehicle_related
# 34182 couldn't find vehicle_related
# 34183 couldn't find vehicle_related
# 34184 couldn't find vehicle_related
# 34185 couldn't find vehicle_related
# 34186 couldn't find vehicle_related
# 34188 couldn't find vehicle_related
# 34191 couldn't find vehicle_related
# 34192 couldn't find vehicle_related
# 34193 couldn't find vehicle_related
# 34194 couldn't find vehicle_related
# 34376 couldn't find two_bladed
# 34587 couldn't find highpitched
# 34655 couldn't find two_bladed
# 34739 couldn't find 70
# 34865 couldn't find highpitched
# 34895 couldn't find redbrown
# 34898 couldn't find felttipped
# 34933 couldn't find two_bladed
# 35142 couldn't find highpitched
# 35142 couldn't find highpitched
# 35172 couldn't find redbrown
# 35175 couldn't find felttipped
# 35210 couldn't find two_bladed
# 35294 couldn't find 70
# 35451 couldn't find felttipped
# 35693 couldn't find highpitched
# 35723 couldn't find redbrown
# 35726 couldn't find felttipped
# 35761 couldn't find two_bladed
# 35845 couldn't find 70
# 35997 couldn't find redbrown
# 36000 couldn't find felttipped
# 36035 couldn't find two_bladed
# 36273 couldn't find felttipped
# 36545 couldn't find felttipped
# 36580 couldn't find two_bladed
# 36783 couldn't find highpitched
# 36783 couldn't find highpitched
# 36813 couldn't find redbrown
# 36816 couldn't find felttipped
# 36851 couldn't find two_bladed
# 36935 couldn't find 70
# 37053 couldn't find highpitched
# 37083 couldn't find redbrown
# 37086 couldn't find felttipped
# 37121 couldn't find two_bladed
# 37121 couldn't find two_bladed
# 37352 couldn't find redbrown
# 37355 couldn't find felttipped
# 37390 couldn't find two_bladed
# 37590 couldn't find highpitched
# 37620 couldn't find redbrown
# 37623 couldn't find felttipped
# 37658 couldn't find two_bladed
# 37925 couldn't find two_bladed
# 38123 couldn't find highpitched
# 38153 couldn't find redbrown
# 38156 couldn't find felttipped
# 38191 couldn't find two_bladed
# 38388 couldn't find highpitched
# 38418 couldn't find redbrown
# 38421 couldn't find felttipped
# 38456 couldn't find two_bladed
# 38540 couldn't find 70
# 38652 couldn't find highpitched
# 38682 couldn't find redbrown
# 38685 couldn't find felttipped
# 38720 couldn't find two_bladed
# 38915 couldn't find highpitched
# 38945 couldn't find redbrown
# 38948 couldn't find felttipped
# 38983 couldn't find two_bladed
# 39177 couldn't find highpitched
# 39207 couldn't find redbrown
# 39210 couldn't find felttipped
# 39245 couldn't find two_bladed
# 39506 couldn't find two_bladed
# 39698 couldn't find highpitched
# 39698 couldn't find highpitched
# 39728 couldn't find redbrown
# 39731 couldn't find felttipped
# 39766 couldn't find two_bladed
# 39850 couldn't find 70
# 40025 couldn't find two_bladed
# 40283 couldn't find two_bladed
# 40502 couldn't find redbrown
# 40505 couldn't find felttipped
# 40540 couldn't find two_bladed
# 40761 couldn't find felttipped
# 40796 couldn't find two_bladed
# 41013 couldn't find redbrown
# 41016 couldn't find felttipped
# 41051 couldn't find two_bladed
# 41305 couldn't find two_bladed
# 41558 couldn't find two_bladed
# 41772 couldn't find redbrown
# 41775 couldn't find felttipped
# 41810 couldn't find two_bladed
# 42061 couldn't find two_bladed
# 42276 couldn't find felttipped
# 42311 couldn't find two_bladed
# 42492 couldn't find highpitched
# 42522 couldn't find redbrown
# 42525 couldn't find felttipped
# 42560 couldn't find two_bladed
# 42644 couldn't find 70
# 42770 couldn't find redbrown
# 42773 couldn't find felttipped
# 42808 couldn't find two_bladed
# 43020 couldn't find felttipped
# 43055 couldn't find two_bladed
# 43263 couldn't find redbrown
# 43266 couldn't find felttipped
# 43301 couldn't find two_bladed
# 43478 couldn't find highpitched
# 43508 couldn't find redbrown
# 43511 couldn't find felttipped
# 43546 couldn't find two_bladed
# 43546 couldn't find two_bladed
# 43722 couldn't find highpitched
# 43752 couldn't find redbrown
# 43755 couldn't find felttipped
# 43790 couldn't find two_bladed
# 43874 couldn't find 70
# 43998 couldn't find felttipped
# 44033 couldn't find two_bladed
# 44207 couldn't find highpitched
# 44237 couldn't find redbrown
# 44240 couldn't find felttipped
# 44275 couldn't find two_bladed
# 44275 couldn't find two_bladed
# 44448 couldn't find highpitched
# 44478 couldn't find redbrown
# 44481 couldn't find felttipped
# 44516 couldn't find two_bladed
# 44600 couldn't find 70
# 44688 couldn't find highpitched
# 44718 couldn't find redbrown
# 44721 couldn't find felttipped
# 44756 couldn't find two_bladed
# 44995 couldn't find two_bladed
# 45198 couldn't find felttipped
# 45233 couldn't find two_bladed
# 45432 couldn't find redbrown
# 45435 couldn't find felttipped
# 45470 couldn't find two_bladed
# 45638 couldn't find highpitched
# 45668 couldn't find redbrown
# 45671 couldn't find felttipped
# 45706 couldn't find two_bladed
# 45790 couldn't find 70
# 45941 couldn't find two_bladed
# 46175 couldn't find two_bladed
# 46370 couldn't find redbrown
# 46373 couldn't find felttipped
# 46408 couldn't find two_bladed
# 46640 couldn't find two_bladed
# 46871 couldn't find two_bladed
# 47033 couldn't find highpitched
# 47063 couldn't find redbrown
# 47066 couldn't find felttipped
# 47101 couldn't find two_bladed
# 47295 couldn't find felttipped
# 47490 couldn't find highpitched
# 47520 couldn't find redbrown
# 47523 couldn't find felttipped
# 47558 couldn't find two_bladed
# 47785 couldn't find two_bladed
# 48011 couldn't find two_bladed
# 48168 couldn't find highpitched
# 48198 couldn't find redbrown
# 48201 couldn't find felttipped
# 48236 couldn't find two_bladed
# 48236 couldn't find two_bladed
# 48422 couldn't find redbrown
# 48425 couldn't find felttipped
# 48460 couldn't find two_bladed
# 48648 couldn't find felttipped
# 48683 couldn't find two_bladed
# 48837 couldn't find highpitched
# 48867 couldn't find redbrown
# 48870 couldn't find felttipped
# 48905 couldn't find two_bladed
# 49058 couldn't find highpitched
# 49058 couldn't find highpitched
# 49088 couldn't find redbrown
# 49091 couldn't find felttipped
# 49126 couldn't find two_bladed
# 49210 couldn't find 70
# 49346 couldn't find two_bladed
# 49565 couldn't find two_bladed
# 49715 couldn't find highpitched
# 49745 couldn't find redbrown
# 49748 couldn't find felttipped
# 49783 couldn't find two_bladed
# 49867 couldn't find 70
# 49932 couldn't find highpitched
# 49962 couldn't find redbrown
# 49965 couldn't find felttipped
# 50000 couldn't find two_bladed
# 50216 couldn't find two_bladed
# 50363 couldn't find highpitched
# 50431 couldn't find two_bladed
# 50515 couldn't find 70
# 50645 couldn't find two_bladed
# 50790 couldn't find highpitched
# 50823 couldn't find felttipped
# 50858 couldn't find two_bladed
# 51002 couldn't find highpitched
# 51032 couldn't find redbrown
# 51035 couldn't find felttipped
# 51070 couldn't find two_bladed
# 51154 couldn't find 70
# 51281 couldn't find two_bladed
# 51423 couldn't find highpitched
# 51453 couldn't find redbrown
# 51456 couldn't find felttipped
# 51491 couldn't find two_bladed
# 51491 couldn't find two_bladed
# 51700 couldn't find two_bladed
# 51840 couldn't find highpitched
# 51870 couldn't find redbrown
# 51873 couldn't find felttipped
# 51908 couldn't find two_bladed
# 51908 couldn't find two_bladed
# 52047 couldn't find highpitched
# 52077 couldn't find redbrown
# 52080 couldn't find felttipped
# 52115 couldn't find two_bladed
# 52283 couldn't find redbrown
# 52286 couldn't find felttipped
# 52321 couldn't find two_bladed
# 52458 couldn't find highpitched
# 52488 couldn't find redbrown
# 52491 couldn't find felttipped
# 52491 couldn't find felttipped
# 52526 couldn't find two_bladed
# 52610 couldn't find 70
# 52692 couldn't find redbrown
# 52695 couldn't find felttipped
# 52730 couldn't find two_bladed
# 52898 couldn't find felttipped
# 52933 couldn't find two_bladed
# 53067 couldn't find highpitched
# 53097 couldn't find redbrown
# 53100 couldn't find felttipped
# 53135 couldn't find two_bladed
# 53268 couldn't find highpitched
# 53298 couldn't find redbrown
# 53301 couldn't find felttipped
# 53336 couldn't find two_bladed
# 53468 couldn't find highpitched
# 53498 couldn't find redbrown
# 53501 couldn't find felttipped
# 53536 couldn't find two_bladed
# 53620 couldn't find 70
# 53667 couldn't find highpitched
# 53735 couldn't find two_bladed
# 53819 couldn't find 70
# 53898 couldn't find felttipped
# 53933 couldn't find two_bladed
# 54130 couldn't find two_bladed
# 54288 couldn't find redbrown
# 54291 couldn't find felttipped
# 54326 couldn't find two_bladed
# 54521 couldn't find two_bladed
# 54715 couldn't find two_bladed
# 54840 couldn't find highpitched
# 54870 couldn't find redbrown
# 54873 couldn't find felttipped
# 54908 couldn't find two_bladed
# 54992 couldn't find 70
# 55032 couldn't find highpitched
# 55062 couldn't find redbrown
# 55065 couldn't find felttipped
# 55100 couldn't find two_bladed
# 55184 couldn't find 70
# 55291 couldn't find two_bladed
# 55481 couldn't find two_bladed
# 55602 couldn't find highpitched
# 55632 couldn't find redbrown
# 55635 couldn't find felttipped
# 55635 couldn't find felttipped
# 55670 couldn't find two_bladed
# 55754 couldn't find 70
# 55790 couldn't find highpitched
# 55820 couldn't find redbrown
# 55823 couldn't find felttipped
# 55858 couldn't find two_bladed
# 55942 couldn't find 70
# 55977 couldn't find highpitched
# 56007 couldn't find redbrown
# 56010 couldn't find felttipped
# 56010 couldn't find felttipped
# 56045 couldn't find two_bladed
# 56129 couldn't find 70
# 56163 couldn't find highpitched
# 56196 couldn't find felttipped
# 56231 couldn't find two_bladed
# 56315 couldn't find 70
# 56348 couldn't find highpitched
# 56378 couldn't find redbrown
# 56381 couldn't find felttipped
# 56416 couldn't find two_bladed
# 56500 couldn't find 70
# 56532 couldn't find highpitched
# 56562 couldn't find redbrown
# 56565 couldn't find felttipped
# 56600 couldn't find two_bladed
# 56684 couldn't find 70
# 56748 couldn't find felttipped
# 56783 couldn't find two_bladed
# 56930 couldn't find felttipped
# 57078 couldn't find highpitched
# 57078 couldn't find highpitched
# 57108 couldn't find redbrown
# 57111 couldn't find felttipped
# 57146 couldn't find two_bladed
# 57230 couldn't find 70
# 57258 couldn't find highpitched
# 57288 couldn't find redbrown
# 57291 couldn't find felttipped
# 57326 couldn't find two_bladed
# 57437 couldn't find highpitched
# 57505 couldn't find two_bladed
# 57589 couldn't find 70
# 57683 couldn't find two_bladed
# 57792 couldn't find highpitched
# 57822 couldn't find redbrown
# 57825 couldn't find felttipped
# 57860 couldn't find two_bladed
# 57968 couldn't find highpitched
# 57998 couldn't find redbrown
# 58001 couldn't find felttipped
# 58036 couldn't find two_bladed
# 58036 couldn't find two_bladed
# 58211 couldn't find two_bladed
# 58347 couldn't find redbrown
# 58350 couldn't find felttipped
# 58385 couldn't find two_bladed
# 58558 couldn't find two_bladed
# 58662 couldn't find highpitched
# 58692 couldn't find redbrown
# 58695 couldn't find felttipped
# 58730 couldn't find two_bladed
# 58901 couldn't find two_bladed
# 59003 couldn't find highpitched
# 59033 couldn't find redbrown
# 59036 couldn't find felttipped
# 59071 couldn't find two_bladed
# 59202 couldn't find redbrown
# 59205 couldn't find felttipped
# 59240 couldn't find two_bladed
# 59408 couldn't find two_bladed
# 59508 couldn't find highpitched
# 59509 couldn't find highpitched
# 59511 couldn't find highpitched
# 59515 couldn't find highpitched
# 59516 couldn't find highpitched
# 59524 couldn't find highpitched
# 59524 couldn't find highpitched
# 59527 couldn't find highpitched
# 59528 couldn't find highpitched
# 59530 couldn't find highpitched
# 59533 couldn't find highpitched
# 59534 couldn't find highpitched
# 59537 couldn't find highpitched
# 59537 couldn't find redbrown
# 59539 couldn't find highpitched
# 59540 couldn't find highpitched
# 59540 couldn't find highpitched
# 59540 couldn't find felttipped
# 59541 couldn't find highpitched
# 59545 couldn't find highpitched
# 59549 couldn't find highpitched
# 59550 couldn't find highpitched
# 59553 couldn't find highpitched
# 59555 couldn't find highpitched
# 59557 couldn't find highpitched
# 59558 couldn't find highpitched
# 59559 couldn't find highpitched
# 59560 couldn't find highpitched
# 59560 couldn't find highpitched
# 59561 couldn't find highpitched
# 59565 couldn't find highpitched
# 59569 couldn't find highpitched
# 59570 couldn't find highpitched
# 59571 couldn't find highpitched
# 59572 couldn't find highpitched
# 59575 couldn't find two_bladed
# 59575 couldn't find highpitched
# 59577 couldn't find highpitched
# 59578 couldn't find highpitched
# 59579 couldn't find highpitched
# 59580 couldn't find highpitched
# 59581 couldn't find highpitched
# 59585 couldn't find highpitched
# 59592 couldn't find highpitched
# 59596 couldn't find highpitched
# 59598 couldn't find highpitched
# 59602 couldn't find highpitched
# 59604 couldn't find highpitched
# 59605 couldn't find highpitched
# 59610 couldn't find highpitched
# 59612 couldn't find highpitched
# 59617 couldn't find highpitched
# 59618 couldn't find highpitched
# 59620 couldn't find highpitched
# 59623 couldn't find highpitched
# 59624 couldn't find highpitched
# 59627 couldn't find highpitched
# 59628 couldn't find highpitched
# 59630 couldn't find highpitched
# 59632 couldn't find highpitched
# 59635 couldn't find highpitched
# 59636 couldn't find highpitched
# 59640 couldn't find highpitched
# 59646 couldn't find highpitched
# 59647 couldn't find highpitched
# 59650 couldn't find highpitched
# 59652 couldn't find highpitched
# 59653 couldn't find highpitched
# 59653 couldn't find highpitched
# 59656 couldn't find highpitched
# 59657 couldn't find highpitched
# 59658 couldn't find highpitched
# 59659 couldn't find highpitched
# 59659 couldn't find 70
# 59662 couldn't find highpitched
# 59667 couldn't find highpitched
# 59668 couldn't find highpitched
# 59670 couldn't find highpitched
# 59672 couldn't find highpitched
# 59673 couldn't find highpitched
# 59674 couldn't find highpitched
# 59703 couldn't find redbrown
# 59706 couldn't find felttipped
# 59741 couldn't find two_bladed
# 59868 couldn't find redbrown
# 59871 couldn't find felttipped
# 59906 couldn't find two_bladed
# 60032 couldn't find redbrown
# 60035 couldn't find felttipped
# 60070 couldn't find two_bladed
# 60195 couldn't find redbrown
# 60198 couldn't find felttipped
# 60198 couldn't find felttipped
# 60233 couldn't find two_bladed
# 60317 couldn't find 70
# 60360 couldn't find felttipped
# 60395 couldn't find two_bladed
# 60556 couldn't find two_bladed
# 60716 couldn't find two_bladed
# 60837 couldn't find redbrown
# 60840 couldn't find felttipped
# 60875 couldn't find two_bladed
# 60995 couldn't find redbrown
# 60998 couldn't find felttipped
# 61033 couldn't find two_bladed
# 61190 couldn't find two_bladed
# 61311 couldn't find felttipped
# 61346 couldn't find two_bladed
# 61501 couldn't find two_bladed
# 61655 couldn't find two_bladed
# 61808 couldn't find two_bladed
# 61925 couldn't find felttipped
# 61960 couldn't find two_bladed
# 62111 couldn't find two_bladed
# 62223 couldn't find redbrown
# 62226 couldn't find felttipped
# 62261 couldn't find two_bladed
# 62345 couldn't find 70
# 62410 couldn't find two_bladed
# 62558 couldn't find two_bladed
# 62667 couldn't find redbrown
# 62670 couldn't find felttipped
# 62670 couldn't find felttipped
# 62705 couldn't find two_bladed
# 62789 couldn't find 70
# 62813 couldn't find redbrown
# 62816 couldn't find felttipped
# 62851 couldn't find two_bladed
# 62958 couldn't find redbrown
# 62961 couldn't find felttipped
# 62996 couldn't find two_bladed
# 63105 couldn't find felttipped
# 63140 couldn't find two_bladed
# 63248 couldn't find felttipped
# 63283 couldn't find two_bladed
# 63387 couldn't find redbrown
# 63390 couldn't find felttipped
# 63425 couldn't find two_bladed
# 63528 couldn't find redbrown
# 63531 couldn't find felttipped
# 63566 couldn't find two_bladed
# 63566 couldn't find two_bladed
# 63668 couldn't find redbrown
# 63671 couldn't find felttipped
# 63706 couldn't find two_bladed
# 63845 couldn't find two_bladed
# 63983 couldn't find two_bladed
# 64084 couldn't find redbrown
# 64085 couldn't find redbrown
# 64085 couldn't find felttipped
# 64086 couldn't find redbrown
# 64090 couldn't find redbrown
# 64091 couldn't find redbrown
# 64094 couldn't find redbrown
# 64097 couldn't find redbrown
# 64098 couldn't find redbrown
# 64101 couldn't find redbrown
# 64102 couldn't find redbrown
# 64103 couldn't find redbrown
# 64105 couldn't find redbrown
# 64106 couldn't find redbrown
# 64110 couldn't find redbrown
# 64116 couldn't find redbrown
# 64117 couldn't find redbrown
# 64119 couldn't find redbrown
# 64120 couldn't find two_bladed
# 64122 couldn't find redbrown
# 64123 couldn't find redbrown
# 64124 couldn't find redbrown
# 64125 couldn't find redbrown
# 64126 couldn't find redbrown
# 64129 couldn't find redbrown
# 64130 couldn't find redbrown
# 64131 couldn't find redbrown
# 64134 couldn't find redbrown
# 64137 couldn't find redbrown
# 64138 couldn't find redbrown
# 64141 couldn't find redbrown
# 64147 couldn't find redbrown
# 64149 couldn't find redbrown
# 64150 couldn't find redbrown
# 64155 couldn't find redbrown
# 64157 couldn't find redbrown
# 64161 couldn't find redbrown
# 64162 couldn't find redbrown
# 64163 couldn't find redbrown
# 64165 couldn't find redbrown
# 64166 couldn't find redbrown
# 64168 couldn't find redbrown
# 64169 couldn't find redbrown
# 64171 couldn't find redbrown
# 64172 couldn't find redbrown
# 64173 couldn't find redbrown
# 64174 couldn't find redbrown
# 64175 couldn't find redbrown
# 64178 couldn't find redbrown
# 64179 couldn't find redbrown
# 64181 couldn't find redbrown
# 64182 couldn't find redbrown
# 64183 couldn't find redbrown
# 64185 couldn't find redbrown
# 64186 couldn't find redbrown
# 64189 couldn't find redbrown
# 64190 couldn't find redbrown
# 64191 couldn't find redbrown
# 64192 couldn't find redbrown
# 64194 couldn't find redbrown
# 64195 couldn't find redbrown
# 64197 couldn't find redbrown
# 64198 couldn't find redbrown
# 64199 couldn't find redbrown
# 64201 couldn't find redbrown
# 64202 couldn't find redbrown
# 64203 couldn't find redbrown
# 64205 couldn't find redbrown
# 64211 couldn't find redbrown
# 64213 couldn't find redbrown
# 64214 couldn't find redbrown
# 64215 couldn't find redbrown
# 64217 couldn't find redbrown
# 64218 couldn't find redbrown
# 64219 couldn't find redbrown
# 64256 couldn't find two_bladed
# 64356 couldn't find felttipped
# 64391 couldn't find two_bladed
# 64475 couldn't find 70
# 64491 couldn't find felttipped
# 64493 couldn't find felttipped
# 64494 couldn't find felttipped
# 64495 couldn't find felttipped
# 64496 couldn't find felttipped
# 64499 couldn't find felttipped
# 64500 couldn't find felttipped
# 64501 couldn't find felttipped
# 64502 couldn't find felttipped
# 64503 couldn't find felttipped
# 64504 couldn't find felttipped
# 64506 couldn't find felttipped
# 64507 couldn't find felttipped
# 64508 couldn't find felttipped
# 64508 couldn't find felttipped
# 64509 couldn't find felttipped
# 64510 couldn't find felttipped
# 64511 couldn't find felttipped
# 64513 couldn't find felttipped
# 64515 couldn't find felttipped
# 64520 couldn't find felttipped
# 64521 couldn't find felttipped
# 64522 couldn't find felttipped
# 64524 couldn't find felttipped
# 64525 couldn't find two_bladed
# 64527 couldn't find felttipped
# 64528 couldn't find felttipped
# 64529 couldn't find felttipped
# 64530 couldn't find felttipped
# 64531 couldn't find felttipped
# 64534 couldn't find felttipped
# 64535 couldn't find felttipped
# 64536 couldn't find felttipped
# 64537 couldn't find felttipped
# 64538 couldn't find felttipped
# 64539 couldn't find felttipped
# 64540 couldn't find felttipped
# 64542 couldn't find felttipped
# 64543 couldn't find felttipped
# 64546 couldn't find felttipped
# 64547 couldn't find felttipped
# 64549 couldn't find felttipped
# 64552 couldn't find felttipped
# 64554 couldn't find felttipped
# 64555 couldn't find felttipped
# 64560 couldn't find felttipped
# 64561 couldn't find felttipped
# 64562 couldn't find felttipped
# 64566 couldn't find felttipped
# 64567 couldn't find felttipped
# 64568 couldn't find felttipped
# 64570 couldn't find felttipped
# 64571 couldn't find felttipped
# 64572 couldn't find felttipped
# 64573 couldn't find felttipped
# 64574 couldn't find felttipped
# 64576 couldn't find felttipped
# 64577 couldn't find felttipped
# 64578 couldn't find felttipped
# 64579 couldn't find felttipped
# 64580 couldn't find felttipped
# 64583 couldn't find felttipped
# 64584 couldn't find felttipped
# 64585 couldn't find felttipped
# 64586 couldn't find felttipped
# 64587 couldn't find felttipped
# 64588 couldn't find felttipped
# 64589 couldn't find felttipped
# 64590 couldn't find felttipped
# 64591 couldn't find felttipped
# 64592 couldn't find felttipped
# 64593 couldn't find felttipped
# 64594 couldn't find felttipped
# 64595 couldn't find felttipped
# 64596 couldn't find felttipped
# 64597 couldn't find felttipped
# 64599 couldn't find felttipped
# 64600 couldn't find felttipped
# 64602 couldn't find felttipped
# 64603 couldn't find felttipped
# 64604 couldn't find felttipped
# 64606 couldn't find felttipped
# 64607 couldn't find felttipped
# 64608 couldn't find felttipped
# 64609 couldn't find 70
# 64609 couldn't find felttipped
# 64610 couldn't find felttipped
# 64612 couldn't find felttipped
# 64613 couldn't find felttipped
# 64614 couldn't find felttipped
# 64616 couldn't find felttipped
# 64617 couldn't find felttipped
# 64618 couldn't find felttipped
# 64619 couldn't find felttipped
# 64620 couldn't find felttipped
# 64622 couldn't find felttipped
# 64623 couldn't find felttipped
# 64624 couldn't find felttipped
# 64658 couldn't find two_bladed
# 64742 couldn't find 70
# 64790 couldn't find two_bladed
# 64921 couldn't find two_bladed
# 65180 couldn't find two_bladed
# 65180 couldn't find two_bladed
# 65308 couldn't find two_bladed
# 65435 couldn't find two_bladed
# 65561 couldn't find two_bladed
# 65686 couldn't find two_bladed
# 65770 couldn't find 70
# 65810 couldn't find two_bladed
# 65933 couldn't find two_bladed
# 66055 couldn't find two_bladed
# 66176 couldn't find two_bladed
# 66296 couldn't find two_bladed
# 66415 couldn't find two_bladed
# 66499 couldn't find 70
# 66533 couldn't find two_bladed
# 66650 couldn't find two_bladed
# 66766 couldn't find two_bladed
# 66850 couldn't find 70
# 66881 couldn't find two_bladed
# 66965 couldn't find 70
# 66995 couldn't find two_bladed
# 67079 couldn't find 70
# 67108 couldn't find two_bladed
# 67192 couldn't find 70
# 67220 couldn't find two_bladed
# 67331 couldn't find two_bladed
# 67441 couldn't find two_bladed
# 67550 couldn't find two_bladed
# 67658 couldn't find two_bladed
# 67765 couldn't find two_bladed
# 67871 couldn't find two_bladed
# 67976 couldn't find two_bladed
# 68080 couldn't find two_bladed
# 68183 couldn't find two_bladed
# 68285 couldn't find two_bladed
# 68386 couldn't find two_bladed
# 68486 couldn't find two_bladed
# 68586 couldn't find two_bladed
# 68587 couldn't find two_bladed
# 68587 couldn't find two_bladed
# 68588 couldn't find two_bladed
# 68589 couldn't find two_bladed
# 68590 couldn't find two_bladed
# 68590 couldn't find two_bladed
# 68591 couldn't find two_bladed
# 68592 couldn't find two_bladed
# 68593 couldn't find two_bladed
# 68594 couldn't find two_bladed
# 68595 couldn't find two_bladed
# 68595 couldn't find two_bladed
# 68596 couldn't find two_bladed
# 68597 couldn't find two_bladed
# 68598 couldn't find two_bladed
# 68599 couldn't find two_bladed
# 68600 couldn't find two_bladed
# 68601 couldn't find two_bladed
# 68602 couldn't find two_bladed
# 68602 couldn't find two_bladed
# 68603 couldn't find two_bladed
# 68604 couldn't find two_bladed
# 68605 couldn't find two_bladed
# 68606 couldn't find two_bladed
# 68606 couldn't find two_bladed
# 68607 couldn't find two_bladed
# 68608 couldn't find two_bladed
# 68609 couldn't find two_bladed
# 68610 couldn't find two_bladed
# 68611 couldn't find two_bladed
# 68612 couldn't find two_bladed
# 68613 couldn't find two_bladed
# 68614 couldn't find two_bladed
# 68615 couldn't find two_bladed
# 68616 couldn't find two_bladed
# 68617 couldn't find two_bladed
# 68618 couldn't find two_bladed
# 68619 couldn't find two_bladed
# 68620 couldn't find two_bladed
# 68621 couldn't find two_bladed
# 68622 couldn't find two_bladed
# 68623 couldn't find two_bladed
# 68624 couldn't find two_bladed
# 68625 couldn't find two_bladed
# 68626 couldn't find two_bladed
# 68627 couldn't find two_bladed
# 68628 couldn't find two_bladed
# 68629 couldn't find two_bladed
# 68630 couldn't find two_bladed
# 68631 couldn't find two_bladed
# 68632 couldn't find two_bladed
# 68633 couldn't find two_bladed
# 68634 couldn't find two_bladed
# 68635 couldn't find two_bladed
# 68636 couldn't find two_bladed
# 68637 couldn't find two_bladed
# 68638 couldn't find two_bladed
# 68639 couldn't find two_bladed
# 68640 couldn't find two_bladed
# 68641 couldn't find two_bladed
# 68642 couldn't find two_bladed
# 68643 couldn't find two_bladed
# 68644 couldn't find two_bladed
# 68645 couldn't find two_bladed
# 68646 couldn't find two_bladed
# 68646 couldn't find two_bladed
# 68647 couldn't find two_bladed
# 68648 couldn't find two_bladed
# 68649 couldn't find two_bladed
# 68650 couldn't find two_bladed
# 68651 couldn't find two_bladed
# 68653 couldn't find two_bladed
# 68654 couldn't find two_bladed
# 68655 couldn't find two_bladed
# 68656 couldn't find two_bladed
# 68657 couldn't find two_bladed
# 68658 couldn't find two_bladed
# 68659 couldn't find two_bladed
# 68660 couldn't find two_bladed
# 68660 couldn't find two_bladed
# 68661 couldn't find two_bladed
# 68662 couldn't find two_bladed
# 68663 couldn't find two_bladed
# 68664 couldn't find two_bladed
# 68665 couldn't find two_bladed
# 68666 couldn't find two_bladed
# 68667 couldn't find two_bladed
# 68668 couldn't find two_bladed
# 68669 couldn't find two_bladed
# 68669 couldn't find 70
# 68670 couldn't find two_bladed
# 68671 couldn't find two_bladed
# 68672 couldn't find two_bladed
# 68673 couldn't find two_bladed
# 68674 couldn't find two_bladed
# 68675 couldn't find two_bladed
# 68676 couldn't find two_bladed
# 68677 couldn't find two_bladed
# 68678 couldn't find two_bladed
# 68679 couldn't find two_bladed
# 68680 couldn't find two_bladed
# 68681 couldn't find two_bladed
# 68682 couldn't find two_bladed
# 68683 couldn't find two_bladed
# 68684 couldn't find two_bladed
# 69149 couldn't find 70
# 71629 couldn't find 70
# 71924 couldn't find 70
# 71980 couldn't find 70
# 72089 couldn't find 70
# 72245 couldn't find 70
# 72439 couldn't find 70
# 72485 couldn't find 70
# 72659 couldn't find 70
# 72779 couldn't find 70
# 73142 couldn't find 70
# 73169 couldn't find 70
# 73289 couldn't find 70
# 73310 couldn't find 70
# 73384 couldn't find 70
# 73418 couldn't find 70
# 73423 couldn't find 70
# 73424 couldn't find 70
# 73428 couldn't find 70
# 73430 couldn't find 70

# %%
## Save role-wise sims to json file
with open("full_"+parse_type+"_pass_"+full_dataset_name+"_rolewise_similarities.json", "w") as file:
    json.dump(all_role_sim_storage_dict, file, indent=3)

# %% [markdown]
# ### Step 4: Load Rolewise Similarities and Sim data

# %% [markdown]
# Load VerbNet rolewise similarities as computed in step 3.

# %%
## Load datasets and similarity functions for training VerbNet

# Load role-wise similarities from json
rolewise_sims_path = path_root+parse_path+"full_"+parse_type+"_pass_"+full_dataset_name+"_rolewise_similarities.json"
with open(rolewise_sims_path, "r") as file:
    all_role_sim_storage_dict_new = json.load(file)
list_of_sem_roles = list(all_role_sim_storage_dict_new['conceptnet']['1'].keys())

# Compositional functions to examine
sims_path = '\Analysis Results\Sentence Similarities\\'
sim_funcs = ['count','mean','mult','conv','ernie_0','ernie_5_norml','ernie_12','ernie_12_norml','infersent',
             'universal','universal_norml','sentbert','sentbert_mpnet_norml','sentbert_norml',
             'dictBERT_norml','openai','openai_norml','defsent_mean','defsent_mean_norml','defsent_cls','defsent_cls_norml',
             'amrbart','amrbart_norml','AMR','smatch','AMR_WLK_Wasser','S3BERT','S3BERT_norml']

# Load similarity data for all comp functions
for comp_func in sim_funcs:
    filename = path_root+sims_path+full_dataset_name+'_'+comp_func+'_similarities.txt'
    try:
        with open(filename, encoding='utf-8') as file:
            sim_storage[comp_func] = np.array([float(line.rstrip('\n')) for line in file])
    except FileNotFoundError:
        print(filename,'not found')
        continue

# Load full expr STS3k dataset to get dev and train split (for STS3k only)
all_expr_data = np.loadtxt(path_root+'\\Sentence Similarity Data\\Fodor2023 - STS3k Large Dataset\\3 - Experimental data\\STS3k_all_full_expr_501.txt',  delimiter=';', dtype='str')
col_dict = dict(zip(all_expr_data[0], np.arange(len(all_expr_data[0]))))
all_indices = list(np.arange(0,len(sentence_pair_parsed_dict['conceptnet'].keys())))

# A few last things
n_expr = sim_storage['expr'].shape[0]
print(sim_storage.keys()) # key storage dict
# Out:
# D:\Study and Projects\School Work\Year 25 - PhD\Data\\Analysis Results\Sentence Similarities\STS3k_all_count_similarities.txt not found
# dict_keys(['expr', 'mean', 'mult', 'conv', 'ernie_0', 'ernie_5_norml', 'ernie_12', 'ernie_12_norml', 'infersent', 'universal', 'universal_norml', 'sentbert', 'sentbert_mpnet_norml', 'sentbert_norml', 'dictBERT_norml', 'openai', 'openai_norml', 'defsent_mean', 'defsent_mean_norml', 'defsent_cls', 'defsent_cls_norml', 'amrbart', 'amrbart_norml', 'AMR', 'smatch', 'AMR_WLK_Wasser', 'S3BERT', 'S3BERT_norml'])

# %%
## Define sets of sentence types and modifiers for STS3k
sent_types = ['CONST_VERB','CONST_SUBJ','CONST_DOBJ','AB_VERB','AB_SUBJ','AB_DOBJ','ADJECTIVE','OTHER','ZERO','SWAP_DOBJ_VERB','SWAP_SUBJ_DOBJ','SWAP_SUBJ_VERB','TRIPLE','QUAD','PARAPHRASE','NEGATIVE','ONLY_MOD']
sent_types_indices = [list(np.where(all_expr_data[1:,col_dict['Sent Type']] == sent_type)[0]) for sent_type in sent_types]
sent_types_dict = dict(zip(sent_types, sent_types_indices))
sent_types_dict['ONLY_MOD'] = sent_types_dict['ONLY_MOD']+[5,6,7,8,9] # add on 'CHECK' data with identical sentences

# Modifier levels (no mods, 1 mod, 2 mods)
modifier_lvl_dict = {0: list(np.where(all_expr_data[1:,col_dict['Mod 1']] == '')[0]),
                     1: np.intersect1d(list(np.where(all_expr_data[1:,col_dict['Mod 1']] != '')[0]), list(np.where(all_expr_data[1:,col_dict['Mod 2']] == '')[0])),
                     2: np.intersect1d(list(np.where(all_expr_data[1:,col_dict['Mod 2']] != '')[0]), list(np.where(all_expr_data[1:,col_dict['Mod 3']] == '')[0])),
                     3: np.intersect1d(list(np.where(all_expr_data[1:,col_dict['Mod 3']] != '')[0]), list(np.where(all_expr_data[1:,col_dict['Mod 4']] == '')[0])),
                     4: np.intersect1d(list(np.where(all_expr_data[1:,col_dict['Mod 4']] != '')[0]), list(np.where(all_expr_data[1:,col_dict['Mod 5']] == '')[0])),
                     5: list(np.where(all_expr_data[1:,col_dict['Mod 5']] != '')[0])}
average_score_by_type = np.zeros((len(sent_types),6))

# Sentence types (para, swaps, triples, quads)
para_indices = list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'PARAPHRASE')[0])
ab_verb_indices = list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'AB_VERB')[0])
ab_subj_indices = list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'AB_SUBJ')[0])
ab_dobj_indices = list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'AB_DOBJ')[0])
single_indices = ab_verb_indices+ab_subj_indices+ab_dobj_indices
const_verb_indices = list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'CONST_VERB')[0]) 
const_subj_indices = list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'CONST_SUBJ')[0]) 
const_dobj_indices = list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'CONST_DOBJ')[0]) 
swap_indices = list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'SWAP_DOBJ_VERB')[0]) + list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'SWAP_SUBJ_DOBJ')[0]) + \
    list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'SWAP_SUBJ_VERB')[0])
triple_indices = list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'TRIPLE')[0])
quad_indices = list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'QUAD')[0])
neg_indices = list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'NEGATIVE')[0])
zero_indices = list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'ZERO')[0])
other_indices = list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'OTHER')[0])
onlymod_indices = list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'ONLY_MOD')[0])
onlymod_1_indices = [x for x in modifier_lvl_dict[1] if x in onlymod_indices]
onlymod_2_indices = [x for x in modifier_lvl_dict[2] if x in onlymod_indices]
onlymod_3_indices = [x for x in modifier_lvl_dict[3] if x in onlymod_indices]
onlymod_4_indices = [x for x in modifier_lvl_dict[4] if x in onlymod_indices]
onlymod_6_indices = [x for x in modifier_lvl_dict[5] if x in onlymod_indices]
adjective_indices = list(np.where(all_expr_data[1:,col_dict['Sent Type']] == 'ADJECTIVE')[0])
simple_quads = np.intersect1d(list(np.where(all_expr_data[1:,col_dict['Mod 1']] == '')[0]), quad_indices)
simple_triples = np.intersect1d(list(np.where(all_expr_data[1:,col_dict['Mod 1']] == '')[0]), triple_indices)
simple_swaps = np.intersect1d(list(np.where(all_expr_data[1:,col_dict['Mod 1']] == '')[0]), swap_indices)

# Types of modifiers (time, manner, place)
place_indices = list(np.where(all_expr_data[1:,col_dict['Mod 1']] == 'PLACE')[0])
time_indices = list(np.where(all_expr_data[1:,col_dict['Mod 1']] == 'TIME')[0])
manner_indices = list(np.where(all_expr_data[1:,col_dict['Mod 1']] == 'MANNER')[0])
addiobj_indices = list(np.where(all_expr_data[1:,col_dict['Mod 1']] == 'add IOBJ')[0])
subja_indices = list(np.where(all_expr_data[1:,col_dict['Mod 1']] == 'SUBJ adj')[0])
dobja_indices = list(np.where(all_expr_data[1:,col_dict['Mod 1']] == 'DOBJ adj')[0])
iobja_indices = list(np.where(all_expr_data[1:,col_dict['Mod 1']] == 'IOBJ adj')[0])
passive_indices = list(np.where(all_expr_data[1:,col_dict['Mod 1']] == 'PASSIVE')[0])
only_mods_lvl_1 = np.intersect1d(modifier_lvl_dict[1], sent_types_dict['ONLY_MOD']) # mod_only sentence pairs

# Word sets (test, train, dev, adversarial)
set_test = list(np.where(all_expr_data[1:,col_dict['Set']] == 'TEST')[0])
set_dev = list(np.where(all_expr_data[1:,col_dict['Set']] == 'DEV')[0])
set_train = list(np.where(all_expr_data[1:,col_dict['Set']] == 'TRAIN')[0])
all_adversarial = list(np.where(all_expr_data[1:,col_dict['Adversarial']] == 'ADV')[0])
non_adversarial = list(np.where(all_expr_data[1:,col_dict['Adversarial']] == 'NADV')[0])
all_adversarial_no_neg = swap_indices+triple_indices+quad_indices+para_indices

revised_adversarial = swap_indices+triple_indices+quad_indices+onlymod_indices+para_indices+neg_indices
revised_adversarial_no_neg = swap_indices+triple_indices+quad_indices+onlymod_indices+para_indices
revised_adversarial_no_neg_no_para = swap_indices+triple_indices+quad_indices+onlymod_indices
revised_non_adversarial = [x for x in all_indices if x not in revised_adversarial]

# %% [markdown]
# ### Step 5: Evaluate VerbNet Similarities (PCA analysis)

# %% [markdown]
# This analysis of the VerbNet similarities is described in the paper.

# %%
## Function to train a model to predict sentence similarities
def train_model(sim_storage, rolewise_sims, embed_model, comb_alg, train_indices, fixed_params, data_type, save_model=False, pca_comps=8, full_sent_augment=True, start_indx=1):
    # Basic regression variables
    n_expr = sim_storage['expr'].shape[0] # number of experimental observations in dataset
    ys = sim_storage['expr']

    # Get xs data for Verbnet roles
    if data_type=='verbnet' or data_type=='verbnet_&_embeds':
        sim_storage_full_list = []
        for pair_id in np.arange(start_indx,n_expr+start_indx): # start at 0 or 1 depending on dataset
            sim_storage_list = dict_sim_to_list(role_weights_dict,rolewise_sims['conceptnet'][str(pair_id)]) 
            sim_storage_full_list.append(sim_storage_list)
        xs_verbnet = np.array(sim_storage_full_list)
    # Get xs data for embeddings PCA components
    if data_type=='embeddings' or data_type=='verbnet_&_embeds':
        if embed_model.split('_')[-1] == 'norml': # remove 'norml' portion for these models as embeddings aren't saved as _norml
            embed_model_mod = embed_model[0:-6]
        else:
            embed_model_mod = embed_model
        all_sentence_embeds = sep.load_embeds(path_root+embeddings_path, dataset_name, embed_model_mod)
        embed_size = np.array(all_sentence_embeds).shape[1]
        if pca_comps>embed_size: # can't have more PCA components than the original embedding size
            pca_comps=embed_size
        pca = PCA(n_components=pca_comps) # perform PCA decomposition
        xs_embeds = pca.fit_transform(np.array(all_sentence_embeds))

    # Augment xs data with full sentence similarity data (if full_sent_augment==True)
    if data_type=='embeddings': # use only embeddings data
        if full_sent_augment==True:
            xs_final = np.column_stack((xs_embeds,sim_storage[embed_model]))
        else:
            xs_final = xs_embeds
    elif data_type=='verbnet': # use only verbnet roles
        if full_sent_augment==True:
            xs_final = np.column_stack((xs_verbnet,sim_storage[embed_model]))
        else:
            xs_final = xs_verbnet
    elif data_type=='verbnet_&_embeds': # use embeddings and verbnet roles
        if full_sent_augment==True:
            xs_agumented = np.column_stack((xs_verbnet,sim_storage[embed_model]))
            xs_final = np.column_stack((xs_agumented,xs_embeds))
        else:
            xs_final = np.column_stack((xs_verbnet,xs_embeds))
        
    # Deal with NaNs
    xs_final_nonan = np.nan_to_num(xs_final, copy=True, nan=0.0, posinf=None, neginf=None)

    # Choose between Linear regression or Neural network
    if comb_alg=='reg':
        trained_model = LinearRegression().fit(xs_final_nonan[train_indices], ys[train_indices])
        params = trained_model.coef_
    elif comb_alg=='none':
        trained_model = LinearRegression().fit(xs_final_nonan[train_indices], ys[train_indices])
        trained_model.coef_ = fixed_params # use pre-defined parameters except for intercept
        params = trained_model.coef_ 
    elif comb_alg=='nn1':
        trained_model = MLPRegressor(hidden_layer_sizes=(10), random_state=1, max_iter=500).fit(xs_final_nonan[train_indices], ys[train_indices])
        params = trained_model.coefs_
    elif comb_alg=='nn2':
        trained_model = MLPRegressor(hidden_layer_sizes=(60,10), random_state=1, max_iter=500).fit(xs_final_nonan[train_indices], ys[train_indices])
        params = trained_model.coefs_
    elif comb_alg=='nn3':
        trained_model = MLPRegressor(hidden_layer_sizes=(100,100,10), random_state=1, max_iter=500).fit(xs_final_nonan[train_indices], ys[train_indices])
        params = trained_model.coefs_
    elif comb_alg=='nn4':
        trained_model = MLPRegressor(hidden_layer_sizes=(1000,100,100,10), random_state=1, max_iter=500).fit(xs_final_nonan[train_indices], ys[train_indices])
        params = trained_model.coefs_
    elif comb_alg=='nn5':
        trained_model = MLPRegressor(hidden_layer_sizes=(100,100,100,100,10), random_state=1, max_iter=500).fit(xs_final_nonan[train_indices], ys[train_indices])
        params = trained_model.coefs_

    # Save model to file
    if save_model==True:
        saved_model_name = 'verbnet_conceptnet_'+embed_model+'_'+comb_alg+'_model.pkl'
        with open(saved_model_name, 'wb') as file:
            pickle.dump(trained_model, file)

    # Get parameter count
    all_para_count = 0
    if comb_alg=='none':
        all_para_count = 0
    elif len(params) > 0:
        for layer in params:
            all_para_count += layer.size
    else:
        all_para_count = len(params)
    
    return trained_model, xs_final_nonan, params, all_para_count

# %%
## Multiple models: Train multiple models using adversarial or test/train split

# Specify train and test data
# train_indices = revised_non_adversarial
# test_indices = revised_adversarial_no_neg
train_indices = set_train
test_indices = set_test

# Define models to investigate
datatype = 'verbnet' # the type of data to pass to the classifier; can be 'verbnet', 'embeddings', 'verbnet_&_embeds'
embed_model_list = ['mean', 'sentbert_mpnet_norml', 'openai_norml', 'defsent_cls_norml', 'ernie_12_norml'] # embedding models to examiine
comb_algorithms = ['none', 'reg', 'nn1', 'nn2', 'nn3','nn4'] # type of classifier to train to predict similarities

# Define parameters for training (Note: this leads to some variation run-to-run)
num_pca = 8 # PCA to extract for embeddings models (irrelevant for 'verbnet')
augment = True # whether to augment verbnet rolewise sims with full sentence similarity

# Loop to compute similarity predictions
print(datatype)
for embed_model in embed_model_list: # sentence similarity embeddings to use
    print('')
    print(embed_model)
    if datatype=='embeddings' and embed_model=='none': # this combination doesn't make sense so ignore
        continue
        
    # Define parameters for training
    if augment==True: # determine which set of fixed params to use depending on whether augment is true or false
        fixed_params = role_weights_list_augment
    else:
        fixed_params = role_weights_list
        
    for comb_alg in comb_algorithms:  # combination method, either nn for neural network or reg for simple regression

        # Train model and compute predictions
        trained_model, final_xs, params, param_count = train_model(sim_storage, all_role_sim_storage_dict_new, embed_model, comb_alg, train_indices, fixed_params,
                                                       data_type=datatype, pca_comps=num_pca, full_sent_augment=augment, start_indx=start_index)
        test_preds = trained_model.predict(final_xs)
            
        # Save average verbnet similarities to file
        save_file_name = dataset_name+'_'+datatype+'_'+str(num_pca)+'_'+embed_model+'_'+comb_alg+'_adversarial_similarities.txt'
        np.savetxt(save_file_name, test_preds, fmt='%f')

        # Compute and print correlation and network size
        correlation = spearmanr(sim_storage['expr'][test_indices], test_preds[test_indices])[0]
        print(comb_alg, '{:.3f}'.format(correlation), param_count)
# Out:
# verbnet
#
# mean
# none 0.682 0
# reg 0.719 9
# nn1 0.688 100
# nn2 0.713 1150
# nn3 0.787 11910
# nn4 0.789 120010
#
# sentbert_mpnet_norml
# none 0.726 0
# reg 0.778 9
# nn1 0.756 100
# nn2 0.780 1150
# nn3 0.851 11910
# nn4 0.851 120010
#
# openai_norml
# none 0.721 0
# reg 0.774 9
# nn1 0.755 100
# nn2 0.772 1150
# nn3 0.858 11910
# nn4 0.847 120010
#
# defsent_cls_norml
# none 0.728 0
# reg 0.787 9
# nn1 0.780 100
# nn2 0.792 1150
# nn3 0.833 11910
# nn4 0.854 120010
#
# ernie_12_norml
# none 0.704 0
# reg 0.749 9
# nn1 0.733 100
# nn2 0.740 1150
# nn3 0.818 11910
# nn4 0.820 120010

# %% [markdown]
# ### Code Archive (Feel free to ignore!)

# %%
## [DEPRECATED] Multiple models: Train set of models using 10-fold cross-validation

# Define models to investigate
datatype = 'embeddings' # the type of data to pass to the classifier; can be 'verbnet', 'embeddings', 'verbnet_&_embeds'
embed_model_list = ['none', 'mean', 'sentbert_mpnet_norml', 'openai_norml', 'defsent_cls_norml', 'ernie_12_norml']
comb_algorithms = ['reg', 'nn1', 'nn2', 'nn3']

# Define parameters for training
num_pca = 3000 # PCA to extract for embeddings models (irrelevant for 'verbnet')
n_fold = 10 # number of test/train folds

# Loop to compute similarity predictions
print(datatype,'10 fold cross-validation')
for embed_model in embed_model_list: # sentence similarity embeddings to use
    if datatype=='embeddings' and embed_model=='none': # this combination doesn't make sense so ignore
        continue
    
    # Define parameters for training
    if augment==True: # determine which set of fixed params to use depending on whether augment is true or false
        fixed_params = role_weights_list_augment
    else:
        fixed_params = role_weights_list
        
    for comb_alg in comb_algorithms:  # combination method, either nn for neural network or reg for simple regression

        # Key storage array
        full_storage_by_subset = np.empty((n_expr,0), float)
        
        # Perform n-fold regression multiple times
        for iteration in np.arange(0,1):
            
            # Define storage vectors and lists
            indices = np.arange(0,n_expr)
            indices_subsets = partition_list(indices,n_fold)
            preds_by_subset = []
            indices_by_subset = []

            for test_indices in indices_subsets:
                # Get indices to train network with
                train_indices = [index for index in indices if index not in test_indices]

                # Train model and compute predictions
                trained_model, final_xs, params, param_count = train_model(sim_storage, all_role_sim_storage_dict_new, embed_model, comb_alg, train_indices, fixed_params,
                                                               data_type=datatype, pca_comps=num_pca, full_sent_augment=augment, start_indx=start_index)
                test_preds = trained_model.predict(final_xs[test_indices])
                
                # Store results by subset
                preds_by_subset.append(test_preds)
                indices_by_subset.append(test_indices)
                
            # Store in flattened arrays and sort by index
            indices_by_subset_flat = np.array(indices_by_subset).flatten()
            preds_by_subset_flat = np.array(preds_by_subset).flatten()
            all_data_by_subset_flat = np.array([indices_by_subset_flat,preds_by_subset_flat]).T
            all_data_by_subset_flat_sort = all_data_by_subset_flat[all_data_by_subset_flat[:,0].argsort()]  # sort by index
            full_storage_by_subset = np.column_stack((full_storage_by_subset, all_data_by_subset_flat_sort[:,1]))

        # Save average verbnet similarities to file
        save_file_name = dataset_name+'_'+datatype+'_'+str(num_pca)+'_'+embed_model+'_'+comb_alg+'_'+str(n_fold)+'fold_similarities.txt'
        np.savetxt(save_file_name, full_storage_by_subset.mean(axis=1), fmt='%f')
        
        # Compute and print correlation and network size
        correlation = spearmanr(sim_storage['expr'][all_indices], full_storage_by_subset.mean(axis=1)[all_indices])[0]
        print(comb_alg, '{:.3f}'.format(correlation), param_count)

# %%
## Load Pre-Trained VerbNet Similarity Model

# Pre-defined weights
role_weights_dict = {'Agent':2, 'Verb':3, 'Patient':2, 'Theme':2, 'Time':0.5, 'Manner':0.5, 'Location':0.5, 'Trajectory':0.5}

# Load pre-trained model to use
verbnet_sim_func = 'conceptnet'
full_sent_sim_func = 'sentbert_mpnet_norml'
model_type = 'nn4'
saved_model_name = 'verbnet_'+verbnet_sim_func+'_'+full_sent_sim_func+'_'+model_type+'_model.pkl'
with open(saved_model_name, 'rb') as file:
    loaded_model = pickle.load(file)

# Prepare xs data for training regression and neural network
sim_storage_full_list = []
n_expr = sim_storage['expr'].shape[0]
for pair_id in np.arange(1,n_expr+1):
    sim_storage_list = dict_sim_to_list(role_weights_dict,all_role_sim_storage_dict_new[verbnet_sim_func+'_uwtd'][str(pair_id)]) 
    sim_storage_full_list.append(sim_storage_list)
xs = np.array(sim_storage_full_list)

# Augment xs data with full sentence similarity data from another model
if full_sent_sim_func=='none':    
    xs_augmented = xs
else:
    xs_augmented = np.column_stack((xs,sim_storage[full_sent_sim_func]))
    
# Deal with NaNs
xs_augmented_nonan = np.nan_to_num(xs_augmented, copy=True, nan=0.0, posinf=None, neginf=None)

# Generate predictions based on model
predictions = loaded_model.predict(xs_augmented_nonan)

# Save predicted similarities to file
# save_file_name = dataset_name+'_'+saved_model_name+'_similarities.txt'
# np.savetxt(save_file_name, predictions, fmt='%f')

# Compute correlation over test set
# spearmanr(sim_storage['expr'][test_indices], predictions[test_indices])[0]
spearmanr(sim_storage['expr'], predictions)[0]
# Out:
# 0.8771659738958207
